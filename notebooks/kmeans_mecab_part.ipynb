# %% [markdown]
# # word2vecの分類　（kmeans Scikit-learn mecab）
#
# Scikit-learnを使用してクラスター分類を行う。
# Mecabによって単語などの分割を行う。
# Kmeansのクラスター数を調べてみる。

# %%
# 使用ライブラリのインストール

# !pip install -U scikit-learn

# !pip install --upgrade gensim

# !pip install  --upgrade mecab

# !brew install mecab
# !brew install mecab-ipadic

# %%
import MeCab
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
import numpy as np
import random

include_pos = ['動詞', '形容詞', '名詞']

def process_noun_batch(model, nouns, num_clusters):
    """
    バッチ内の名詞に対してクラスタリングを実行し、結果を返す。
    """
    # 名詞のベクトルを取得
    noun_vectors = np.array([model[word] for word in nouns])

    if noun_vectors.size == 0:
        print("名詞ベクトルが空です。")
        return None, None, None, {}

    # K-meansクラスタリングの実行
    kmeans = KMeans(n_clusters=num_clusters, random_state=0)
    kmeans.fit(noun_vectors)

    # 各名詞が属するクラスタを取得
    cluster_indices = kmeans.labels_

    # 名詞とクラスタの対応を取得
    noun_cluster_map = {noun: cluster_indices[i] for i, noun in enumerate(nouns)}

    # 結果を表示 (例: 最初の10名詞)
    for noun, cluster in list(noun_cluster_map.items())[:10]:
        print(f"Noun: {noun}, Cluster: {cluster}")

    return noun_vectors, kmeans, cluster_indices, noun_cluster_map

def kmeans_cluster_nouns(model_path, num_clusters, batch_size=1000):
    """
    名詞をバッチごとに処理し、K-meansクラスタリングを行う。
    クラスタごとに最大100個の名詞をサンプリングして表示する。
    """
    # Word2Vecモデルの読み込み
    model = KeyedVectors.load_word2vec_format(model_path, binary=False)

    # MeCabの初期化
    mecab = MeCab.Tagger('-r /opt/homebrew/etc/mecabrc -d /opt/homebrew/lib/mecab/dic/ipadic')

    # 名詞を格納するリスト
    nouns = []

    # バッチごとの結果を格納するリスト
    all_noun_vectors = []
    all_cluster_indices = []
    all_noun_cluster_map = {}  # クラスタごとの名詞を格納するマップ

    # モデル内の単語を1つずつ解析
    for idx, word in enumerate(model.index_to_key):
        parsed = mecab.parse(word)
        for line in parsed.splitlines():
            if line == 'EOS':  # MeCabの解析終了マーク
                break
            fields = line.split('\t')
            if len(fields) > 1:
                pos_info = fields[1].split(',')  # 品詞情報を取得
                if pos_info[0] == '名詞' and pos_info[1] == '一般':  # 一般名詞の条件を追加
                        nouns.append(word)
                        break

        # バッチサイズに到達したら処理
        if len(nouns) >= batch_size:
            print(f"Processing batch {idx // batch_size + 1}...")  # バッチ進行状況の表示
            noun_vectors, kmeans, cluster_indices, noun_cluster_map = process_noun_batch(model, nouns, num_clusters)
            if noun_vectors is not None:
                all_noun_vectors.append(noun_vectors)
                all_cluster_indices.append(cluster_indices)
                for noun, cluster in noun_cluster_map.items():
                    if cluster not in all_noun_cluster_map:
                        all_noun_cluster_map[cluster] = []
                    all_noun_cluster_map[cluster].append(noun)
            nouns.clear()  # 次のバッチのためにリストをクリア

    # 最後に残った名詞を処理（バッチに満たない場合）
    if nouns:
        print("Processing final batch...")
        noun_vectors, kmeans, cluster_indices, noun_cluster_map = process_noun_batch(model, nouns, num_clusters)
        if noun_vectors is not None:
            all_noun_vectors.append(noun_vectors)
            all_cluster_indices.append(cluster_indices)
            for noun, cluster in noun_cluster_map.items():
                if cluster not in all_noun_cluster_map:
                    all_noun_cluster_map[cluster] = []
                all_noun_cluster_map[cluster].append(noun)

    # クラスタごとに最大100個の名詞をサンプリングして表示
    print("----- クラスタごとのサンプリング結果 -----")
    for cluster, nouns_in_cluster in all_noun_cluster_map.items():
        print(f"\nCluster {cluster}:")
        sampled_nouns = random.sample(nouns_in_cluster, min(100, len(nouns_in_cluster)))  # 最大100個をサンプリング
        for noun in sampled_nouns:
            print(f"  {noun}")

    # 結果を連結して最終結果とする
    if all_noun_vectors:
        all_noun_vectors = np.vstack(all_noun_vectors)
        all_cluster_indices = np.concatenate(all_cluster_indices)
        print(f"Total vectors: {all_noun_vectors.shape}, Total clusters: {len(all_cluster_indices)}")
    else:
        all_noun_vectors = None
        all_cluster_indices = None

    return all_noun_vectors, kmeans, all_cluster_indices
# Out:
# /Users/mfujimak/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# 例として関数を呼び出す

model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
num_clusters = 10  # クラスタ数を指定
batch_size = 1000  # バッチサイズを指定

noun_vectors, kmeans, cluster_indices = kmeans_cluster_nouns(model_path, num_clusters, batch_size=batch_size)
# Out:
# Processing batch 3...
# Noun: もの, Cluster: 2
# Noun: 中, Cluster: 3
# Noun: 者, Cluster: 2
# Noun: 時, Cluster: 3
# Noun: 名, Cluster: 3
# Noun: ば, Cluster: 2
# Noun: 間, Cluster: 3
# Noun: 上, Cluster: 3
# Noun: 内, Cluster: 3
# Noun: 他, Cluster: 3
# Processing batch 5...
# Noun: 南西, Cluster: 8
# Noun: [鉄道], Cluster: 8
# Noun: 墓, Cluster: 2
# Noun: 隣, Cluster: 8
# Noun: ざる, Cluster: 4
# Noun: 中央部, Cluster: 8
# Noun: 質, Cluster: 1
# Noun: 信号, Cluster: 3
# Noun: 同時, Cluster: 1
# Noun: 政治的, Cluster: 4
# Processing batch 8...
# Noun: [文化_(元号)], Cluster: 3
# Noun: [東日本大震災], Cluster: 9
# Noun: 責任者, Cluster: 6
# Noun: フィート, Cluster: 7
# Noun: 濃度, Cluster: 7
# Noun: 背後, Cluster: 0
# Noun: 職務, Cluster: 2
# Noun: 山地, Cluster: 8
# Noun: [競馬の競走], Cluster: 1
# Noun: 電源, Cluster: 4
# Processing batch 10...
# Noun: 負, Cluster: 8
# Noun: [6月1日], Cluster: 7
# Noun: ラン, Cluster: 1
# Noun: 平坦, Cluster: 0
# Noun: ラスト, Cluster: 1
# Noun: 荷物, Cluster: 8
# Noun: 痕跡, Cluster: 8
# Noun: レッド, Cluster: 6
# Noun: [千葉ロッテマリーンズ], Cluster: 1
# Noun: 繋がり, Cluster: 4
# Processing batch 12...
# Noun: 優, Cluster: 9
# Noun: テーマ曲, Cluster: 2
# Noun: [パン], Cluster: 3
# Noun: エンディングテーマ, Cluster: 2
# Noun: [レストラン], Cluster: 4
# Noun: 言動, Cluster: 1
# Noun: 地上波, Cluster: 4
# Noun: [4月10日], Cluster: 5
# Noun: 実体, Cluster: 3
# Noun: 関連会社, Cluster: 4
# Processing batch 14...
# Noun: 裸, Cluster: 5
# Noun: リゾート, Cluster: 1
# Noun: ホイール, Cluster: 8
# Noun: [報道番組], Cluster: 6
# Noun: [1月10日], Cluster: 0
# Noun: 一塁, Cluster: 9
# Noun: 恒星, Cluster: 4
# Noun: スローガン, Cluster: 2
# Noun: サラ, Cluster: 8
# Noun: 頭角, Cluster: 9
# Processing batch 15...
# Noun: 度合い, Cluster: 3
# Noun: 天然記念物, Cluster: 6
# Noun: 長兄, Cluster: 9
# Noun: 元祖, Cluster: 1
# Noun: 掲示板, Cluster: 0
# Noun: 少尉, Cluster: 5
# Noun: 引き渡し, Cluster: 5
# Noun: タバコ, Cluster: 8
# Noun: 波長, Cluster: 6
# Noun: [データベース], Cluster: 3
# Processing batch 17...
# Noun: [国際法], Cluster: 1
# Noun: クリスチャン, Cluster: 9
# Noun: 1月30日, Cluster: 4
# Noun: 年代記, Cluster: 6
# Noun: 交通機関, Cluster: 1
# Noun: 代表チーム, Cluster: 9
# Noun: 品目, Cluster: 1
# Noun: 即時, Cluster: 1
# Noun: 対象者, Cluster: 1
# Noun: [法学者], Cluster: 9
# Processing batch 19...
# Noun: [国会], Cluster: 6
# Noun: [トランスミッション], Cluster: 1
# Noun: 6月9日, Cluster: 8
# Noun: 1月27日, Cluster: 8
# Noun: 船首, Cluster: 3
# Noun: [阪神甲子園球場], Cluster: 3
# Noun: 勅令, Cluster: 9
# Noun: 手がかり, Cluster: 5
# Noun: サル, Cluster: 5
# Noun: 同級, Cluster: 8
# Processing batch 21...
# Noun: リッター, Cluster: 9
# Noun: 最優秀賞, Cluster: 6
# Noun: 責め, Cluster: 5
# Noun: 電極, Cluster: 0
# Noun: [ウィリアムズF1], Cluster: 8
# Noun: 計器, Cluster: 0
# Noun: [民間放送], Cluster: 3
# Noun: 墨, Cluster: 4
# Noun: 機関砲, Cluster: 0
# Noun: リサイタル, Cluster: 8
# Processing batch 23...
# Noun: 俯仰, Cluster: 0
# Noun: 町人, Cluster: 3
# Noun: 尉, Cluster: 8
# Noun: [市制], Cluster: 7
# Noun: 五十音順, Cluster: 6
# Noun: プロ選手, Cluster: 1
# Noun: [ドイツ騎士団], Cluster: 2
# Noun: 鋸歯, Cluster: 4
# Noun: 主観, Cluster: 9
# Noun: 名産, Cluster: 7
# Processing batch 25...
# Noun: スクリプト, Cluster: 7
# Noun: リーディング, Cluster: 3
# Noun: 覇者, Cluster: 3
# Noun: 杭, Cluster: 8
# Noun: [商法], Cluster: 6
# Noun: 同区, Cluster: 8
# Noun: 禁, Cluster: 1
# Noun: 中等, Cluster: 9
# Noun: [自動列車停止装置], Cluster: 7
# Noun: 末寺, Cluster: 1
# Processing batch 27...
# Noun: 四半期, Cluster: 6
# Noun: [山脈], Cluster: 7
# Noun: [ヴァンフォーレ甲府], Cluster: 1
# Noun: 3世紀, Cluster: 0
# Noun: 真っ先, Cluster: 6
# Noun: 仕上がり, Cluster: 3
# Noun: [玄宗_(唐)], Cluster: 8
# Noun: フェーズ, Cluster: 5
# Noun: [中央自動車道], Cluster: 7
# Noun: 湖沼, Cluster: 7
# Processing batch 29...
# Noun: 図像, Cluster: 3
# Noun: [Python], Cluster: 7
# Noun: 幅広, Cluster: 7
# Noun: 汽車, Cluster: 6
# Noun: 列島, Cluster: 8
# Noun: [装甲車], Cluster: 7
# Noun: 欠, Cluster: 2
# Noun: ネジ, Cluster: 7
# Noun: 芸術的, Cluster: 3
# Noun: ミリメートル, Cluster: 7
# Processing batch 31...
# Noun: [薬莢], Cluster: 1
# Noun: [カタパルト], Cluster: 1
# Noun: [ケイ素], Cluster: 4
# Noun: [男子プロテニス協会], Cluster: 7
# Noun: 国立大学, Cluster: 0
# Noun: 編者, Cluster: 2
# Noun: [飼料], Cluster: 8
# Noun: 芸術作品, Cluster: 5
# Noun: 水陸, Cluster: 6
# Noun: [尊卑分脈], Cluster: 2
# Processing batch 33...
# Noun: [直列6気筒], Cluster: 1
# Noun: [民事再生法], Cluster: 6
# Noun: 命日, Cluster: 2
# Noun: 内相, Cluster: 2
# Noun: [無神論], Cluster: 9
# Noun: [国際天文学連合], Cluster: 6
# Noun: 学期, Cluster: 0
# Noun: 強敵, Cluster: 7
# Noun: 重工業, Cluster: 6
# Noun: 子規, Cluster: 9
# Processing batch 35...
# Noun: [グループ], Cluster: 6
# Noun: 国民議会, Cluster: 8
# Noun: ロングセラー, Cluster: 6
# Noun: みらい, Cluster: 0
# Noun: [ブラックメタル], Cluster: 6
# Noun: 洞穴, Cluster: 1
# Noun: 初等教育, Cluster: 6
# Noun: [キャンペーン], Cluster: 6
# Noun: 浴室, Cluster: 7
# Noun: 気力, Cluster: 0
# Processing batch 37...
# Noun: [週刊誌], Cluster: 4
# Noun: [ニューポート_(ロードアイランド州)], Cluster: 6
# Noun: 別働隊, Cluster: 6
# Noun: 政治部, Cluster: 6
# Noun: [ガス燃料], Cluster: 1
# Noun: [Mr.Children], Cluster: 3
# Noun: ミラクル, Cluster: 0
# Noun: [第38任務部隊], Cluster: 6
# Noun: [歴史学者], Cluster: 9
# Noun: 走路, Cluster: 7
# Processing batch 39...
# Noun: [ASCII], Cluster: 9
# Noun: [新自由主義], Cluster: 0
# Noun: [白色矮星], Cluster: 6
# Noun: 未来へ, Cluster: 2
# Noun: 身の回り, Cluster: 3
# Noun: いくらか, Cluster: 2
# Noun: [新潮文庫], Cluster: 7
# Noun: [動物学], Cluster: 7
# Noun: [ニキータ・フルシチョフ], Cluster: 0
# Noun: 裸体, Cluster: 2
# Processing batch 41...
# Noun: パドレス, Cluster: 9
# Noun: [ジョン・マケイン], Cluster: 9
# Noun: [パラドックス], Cluster: 5
# Noun: 陸揚げ, Cluster: 0
# Noun: [領事館], Cluster: 0
# Noun: 直球, Cluster: 9
# Noun: [出囃子_(落語)], Cluster: 8
# Noun: テニス部, Cluster: 9
# Noun: [長官], Cluster: 3
# Noun: 葡萄, Cluster: 4
# Processing batch 43...
# Noun: 港内, Cluster: 5
# Noun: 反政府勢力, Cluster: 8
# Noun: [ブルターニュ公国], Cluster: 8
# Noun: [イスラム世界], Cluster: 8
# Noun: 迷信, Cluster: 3
# Noun: [BGM], Cluster: 7
# Noun: 運動神経, Cluster: 3
# Noun: [公安委員会], Cluster: 9
# Noun: 情報機関, Cluster: 8
# Noun: [本土], Cluster: 6
# Processing batch 45...
# Noun: [貞観_(唐)], Cluster: 2
# Noun: [クラブチーム_(社会人野球)], Cluster: 1
# Noun: 巨木, Cluster: 6
# Noun: [ビデオカメラ], Cluster: 4
# Noun: [絵本作家], Cluster: 8
# Noun: [サッカーポーランド代表], Cluster: 1
# Noun: 鼎, Cluster: 3
# Noun: 自由形, Cluster: 1
# Noun: 幼児期, Cluster: 8
# Noun: [カリフォルニア工科大学], Cluster: 7
# Processing batch 46...
# Noun: 楔, Cluster: 9
# Noun: 踵, Cluster: 9
# Noun: 製菓, Cluster: 3
# Noun: 生粋, Cluster: 9
# Noun: [シカゴ・ベアーズ], Cluster: 8
# Noun: [サッカールーマニア代表], Cluster: 8
# Noun: [バレーボール全日本女子], Cluster: 8
# Noun: [阪神ジュベナイルフィリーズ], Cluster: 8
# Noun: [軽機関銃], Cluster: 2
# Noun: [運動_(物理学)], Cluster: 7
# Processing batch 48...
# Noun: 進駐軍, Cluster: 2
# Noun: [リンパ球], Cluster: 7
# Noun: 型破り, Cluster: 0
# Noun: [水洗式便所], Cluster: 4
# Noun: 人馬, Cluster: 4
# Noun: [NVIDIA], Cluster: 8
# Noun: パドル, Cluster: 5
# Noun: 分離主義, Cluster: 6
# Noun: 練兵, Cluster: 2
# Noun: [アスレティック・ビルバオ], Cluster: 3
# Processing batch 50...
# Noun: 提供クレジット, Cluster: 4
# Noun: 英語教育, Cluster: 9
# Noun: 足並み, Cluster: 9
# Noun: スタジオアルバム, Cluster: 4
# Noun: [ハートフォード_(コネチカット州)], Cluster: 8
# Noun: 現行法, Cluster: 6
# Noun: タイムアタック, Cluster: 8
# Noun: 旧版, Cluster: 4
# Noun: [月刊誌], Cluster: 4
# Noun: 怪盗, Cluster: 7
# Processing batch 52...
# Noun: エコノミスト, Cluster: 1
# Noun: 無冠, Cluster: 3
# Noun: お陰, Cluster: 5
# Noun: 橇, Cluster: 0
# Noun: [日本テレビ系列], Cluster: 1
# Noun: パート2, Cluster: 5
# Noun: 三角関係, Cluster: 5
# Noun: 職域, Cluster: 1
# Noun: 価格競争, Cluster: 1
# Noun: [高輪], Cluster: 1
# Processing batch 54...
# Noun: [特別指定選手], Cluster: 1
# Noun: [臣], Cluster: 0
# Noun: [西区_(神戸市)], Cluster: 3
# Noun: [航空機関砲], Cluster: 1
# Noun: 経済問題, Cluster: 8
# Noun: [大目付], Cluster: 0
# Noun: [雑木林], Cluster: 3
# Noun: [助教], Cluster: 8
# Noun: 切妻, Cluster: 5
# Noun: [土偶], Cluster: 5
# Processing batch 56...
# Noun: 器量, Cluster: 2
# Noun: [ダイエー_(店舗ブランド)], Cluster: 1
# Noun: シンクタンク, Cluster: 9
# Noun: [土砂災害], Cluster: 9
# Noun: [振幅], Cluster: 6
# Noun: 欧州諸国, Cluster: 9
# Noun: [祭礼], Cluster: 2
# Noun: [村上天皇], Cluster: 2
# Noun: [渡り], Cluster: 6
# Noun: [東海3県], Cluster: 1
# Processing batch 58...
# Noun: 全量, Cluster: 2
# Noun: [ヌエバ・エスパーニャ], Cluster: 4
# Noun: 原点回帰, Cluster: 3
# Noun: オンラインショップ, Cluster: 3
# Noun: [津軽三味線], Cluster: 3
# Noun: [若者], Cluster: 8
# Noun: ホッパー, Cluster: 7
# Noun: 特捜, Cluster: 5
# Noun: 蓄電池, Cluster: 7
# Noun: [自然哲学], Cluster: 8
# Processing batch 60...
# Noun: 薦, Cluster: 4
# Noun: [アンドロイド], Cluster: 2
# Noun: バーナー, Cluster: 8
# Noun: [財閥解体], Cluster: 1
# Noun: ターニングポイント, Cluster: 2
# Noun: [頭髪], Cluster: 6
# Noun: [ウディネーゼ・カルチョ], Cluster: 7
# Noun: 軽工業, Cluster: 0
# Noun: [移動図書館], Cluster: 0
# Noun: [カイロプラクティック], Cluster: 9
# Processing batch 61...
# Noun: [大局将棋], Cluster: 1
# Noun: マンモス, Cluster: 0
# Noun: [イピロス], Cluster: 7
# Noun: [実況], Cluster: 8
# Noun: 安寧, Cluster: 1
# Noun: 民間放送, Cluster: 3
# Noun: ハリ, Cluster: 0
# Noun: [ツンドラ], Cluster: 5
# Noun: [国会, Cluster: 3
# Noun: 人事権, Cluster: 3
# Processing batch 63...
# Noun: 副総理, Cluster: 1
# Noun: [ビュンデ], Cluster: 9
# Noun: [活断層], Cluster: 4
# Noun: [計画都市], Cluster: 9
# Noun: [台湾海峡], Cluster: 1
# Noun: [平面交差], Cluster: 9
# Noun: [ハーメルン], Cluster: 1
# Noun: [国際労働機関], Cluster: 1
# Noun: 背信, Cluster: 2
# Noun: [内閣不信任決議], Cluster: 7
# Processing batch 65...
# Noun: [ちびまる子ちゃん], Cluster: 6
# Noun: [エラム], Cluster: 5
# Noun: サブミッション, Cluster: 7
# Noun: 脊椎動物, Cluster: 3
# Noun: 文楽, Cluster: 1
# Noun: [三陸], Cluster: 5
# Noun: キックボクシング, Cluster: 7
# Noun: 身体検査, Cluster: 9
# Noun: [ブルワリー], Cluster: 5
# Noun: [正方行列], Cluster: 3
# Processing batch 67...
# Noun: [ライフセービング], Cluster: 2
# Noun: [フラップ], Cluster: 0
# Noun: [テロップ], Cluster: 9
# Noun: 立木, Cluster: 0
# Noun: [コロンビア_(オービタ)], Cluster: 7
# Noun: カマ, Cluster: 7
# Noun: [語順], Cluster: 5
# Noun: 弦楽四重奏曲, Cluster: 9
# Noun: [位牌], Cluster: 4
# Noun: 夜行列車, Cluster: 2
# Processing batch 69...
# Noun: [クロード・モネ], Cluster: 8
# Noun: [足柄_(重巡洋艦)], Cluster: 9
# Noun: [ワープロソフト], Cluster: 6
# Noun: 艦隊司令部, Cluster: 9
# Noun: 尼寺, Cluster: 2
# Noun: 心筋梗塞, Cluster: 7
# Noun: [コバルト文庫], Cluster: 0
# Noun: [信託銀行], Cluster: 1
# Noun: 色とりどり, Cluster: 3
# Noun: 白血病, Cluster: 7
# Processing batch 71...
# Noun: 加速器, Cluster: 1
# Noun: 大赦, Cluster: 8
# Noun: [PDC], Cluster: 1
# Noun: [ポイント], Cluster: 1
# Noun: [詞], Cluster: 4
# Noun: [熊], Cluster: 6
# Noun: [ゴリツィア], Cluster: 5
# Noun: [日本新聞協会], Cluster: 2
# Noun: [サポーター_(サッカー)], Cluster: 9
# Noun: [封筒], Cluster: 3
# Processing batch 73...
# Noun: [人力飛行機], Cluster: 2
# Noun: 園地, Cluster: 6
# Noun: [T-800], Cluster: 2
# Noun: 憲法修正, Cluster: 5
# Noun: 新日, Cluster: 8
# Noun: 天変地異, Cluster: 3
# Noun: 今世紀, Cluster: 8
# Noun: [寮歌], Cluster: 7
# Noun: 愛国主義, Cluster: 5
# Noun: [オーステンデ], Cluster: 5
# Processing batch 75...
# Noun: [生神女], Cluster: 6
# Noun: [アララギ], Cluster: 1
# Noun: [篆書], Cluster: 6
# Noun: [ハルク_(マーベル・コミック)], Cluster: 4
# Noun: [第19回参議院議員通常選挙], Cluster: 0
# Noun: フロントエンド, Cluster: 7
# Noun: [チューニング], Cluster: 9
# Noun: [続柄], Cluster: 6
# Noun: 江上, Cluster: 6
# Noun: [操縦桿], Cluster: 9
# Processing batch 76...
# Noun: トーキー, Cluster: 5
# Noun: [政党連合], Cluster: 4
# Noun: [パシャ], Cluster: 7
# Noun: オペラハウス, Cluster: 5
# Noun: [地金], Cluster: 2
# Noun: [Category:ThinkPad], Cluster: 1
# Noun: [朝鮮民主主義人民共和国国防委員会], Cluster: 4
# Noun: [合名会社], Cluster: 8
# Noun: 日本語化, Cluster: 1
# Noun: [木本], Cluster: 3
# Processing batch 78...
# Noun: [学園], Cluster: 5
# Noun: [後小松天皇], Cluster: 3
# Noun: 総連, Cluster: 2
# Noun: [縄文人], Cluster: 9
# Noun: 杢, Cluster: 3
# Noun: [一級鉄十字章], Cluster: 7
# Noun: 分党, Cluster: 7
# Noun: 企業誘致, Cluster: 2
# Noun: [ミニーマウス], Cluster: 5
# Noun: [礼服], Cluster: 3
# Processing batch 80...
# Noun: 墓誌, Cluster: 5
# Noun: [サバ州], Cluster: 1
# Noun: 中間派, Cluster: 3
# Noun: 夕焼け, Cluster: 4
# Noun: [ニューラルネットワーク], Cluster: 6
# Noun: 消防本部, Cluster: 2
# Noun: 音楽教室, Cluster: 0
# Noun: オバマ政権, Cluster: 3
# Noun: [リエーティ県], Cluster: 1
# Noun: 大戦果, Cluster: 7
# Processing batch 82...
# Noun: 生け贄, Cluster: 1
# Noun: [ランゴバルド王国], Cluster: 0
# Noun: 法的地位, Cluster: 9
# Noun: [円卓の騎士], Cluster: 0
# Noun: スイミング, Cluster: 2
# Noun: [ディケーター], Cluster: 0
# Noun: [霊性], Cluster: 4
# Noun: [駅馬車], Cluster: 6
# Noun: [天部], Cluster: 7
# Noun: [ひぐらしのなく頃に], Cluster: 5
# Processing batch 84...
# Noun: [成長ホルモン], Cluster: 2
# Noun: [デカン高原], Cluster: 9
# Noun: [NECグリーンロケッツ], Cluster: 8
# Noun: [ファウルボール], Cluster: 8
# Noun: 宿所, Cluster: 0
# Noun: [アレクサンデル6世_(ローマ教皇)], Cluster: 9
# Noun: 甲子園球場, Cluster: 8
# Noun: [ハードポイント], Cluster: 1
# Noun: [日本建築学会賞], Cluster: 5
# Noun: 角質, Cluster: 2
# Processing batch 86...
# Noun: [特別の機関], Cluster: 0
# Noun: [補酵素], Cluster: 5
# Noun: [梅干し], Cluster: 5
# Noun: レンタルビデオ, Cluster: 1
# Noun: 直火, Cluster: 5
# Noun: [国道354号], Cluster: 8
# Noun: [ビルマの戦い], Cluster: 7
# Noun: [構成素], Cluster: 3
# Noun: 青年会議所, Cluster: 8
# Noun: [伝統工芸品], Cluster: 8
# Processing batch 88...
# Noun: 兄弟分, Cluster: 0
# Noun: [バーミンガム大学], Cluster: 1
# Noun: 陽炎, Cluster: 3
# Noun: [賀抜岳], Cluster: 0
# Noun: 封地, Cluster: 0
# Noun: T細胞, Cluster: 5
# Noun: [鹽竈神社], Cluster: 0
# Noun: かっぱ, Cluster: 9
# Noun: [イ_(音名)], Cluster: 4
# Noun: 理想像, Cluster: 2
# Processing batch 90...
# Noun: 巡査部長, Cluster: 2
# Noun: [洗足学園音楽大学], Cluster: 3
# Noun: [行政改革], Cluster: 5
# Noun: [家人], Cluster: 7
# Noun: [JJ_(雑誌)], Cluster: 3
# Noun: 次号, Cluster: 3
# Noun: [日本の競馬], Cluster: 4
# Noun: [SSRI], Cluster: 8
# Noun: [占い師], Cluster: 3
# Noun: [煙台市], Cluster: 6
# Processing batch 91...
# Noun: [GPGPU], Cluster: 9
# Noun: 歓心, Cluster: 6
# Noun: 高利貸し, Cluster: 6
# Noun: 神通力, Cluster: 6
# Noun: シェーク, Cluster: 3
# Noun: マウンテンバイク, Cluster: 2
# Noun: マリファナ, Cluster: 3
# Noun: [仮面ライダーW], Cluster: 6
# Noun: [国道48号], Cluster: 1
# Noun: 恵蔵, Cluster: 6
# Processing batch 93...
# Noun: 鯖, Cluster: 5
# Noun: [平治物語], Cluster: 6
# Noun: 残雪, Cluster: 5
# Noun: [全日本大学野球連盟], Cluster: 9
# Noun: [DAIGO], Cluster: 4
# Noun: [ジャクソンビル・ジャガーズ], Cluster: 9
# Noun: [野坂昭如], Cluster: 4
# Noun: [ブロッケンJr.], Cluster: 4
# Noun: [切り絵], Cluster: 4
# Noun: [ソリューション], Cluster: 1
# Processing batch 95...
# Noun: [仮設住宅], Cluster: 8
# Noun: ゅいちらん, Cluster: 6
# Noun: ネットショップ, Cluster: 9
# Noun: [ロックフェラー財団], Cluster: 1
# Noun: [キンクス], Cluster: 9
# Noun: JRバス, Cluster: 8
# Noun: 妻板, Cluster: 5
# Noun: [USレッチェ], Cluster: 6
# Noun: 試論, Cluster: 1
# Noun: [ジャンカルロ・フィジケラ], Cluster: 6
# Processing batch 97...
# Noun: アダルトビデオ, Cluster: 1
# Noun: 液相, Cluster: 3
# Noun: [通信カラオケ], Cluster: 5
# Noun: [ロンドンブーツ1号2号], Cluster: 1
# Noun: 調停委員, Cluster: 0
# Noun: [集英社文庫], Cluster: 1
# Noun: [ウラン濃縮], Cluster: 0
# Noun: 旅番組, Cluster: 1
# Noun: [党の指導性], Cluster: 0
# Noun: 駐在武官, Cluster: 4
# Processing batch 99...
# Noun: [王世充], Cluster: 6
# Noun: た元, Cluster: 1
# Noun: [朝鮮籍], Cluster: 8
# Noun: [FC東京の下部組織], Cluster: 5
# Noun: [シュテフィ・グラフ], Cluster: 5
# Noun: [尺骨], Cluster: 1
# Noun: [勢力均衡], Cluster: 7
# Noun: [耳介], Cluster: 1
# Noun: 軽車両, Cluster: 2
# Noun: ちちょう, Cluster: 1
# Processing batch 100...
# Noun: 前説, Cluster: 1
# Noun: 最終目的地, Cluster: 2
# Noun: [東武8000系電車], Cluster: 2
# Noun: [部派仏教], Cluster: 9
# Noun: 逃げ道, Cluster: 6
# Noun: [詠春拳], Cluster: 7
# Noun: [r], Cluster: 5
# Noun: [人間科学部], Cluster: 7
# Noun: [パーチ], Cluster: 2
# Noun: [腰椎], Cluster: 8
# Processing batch 102...
# Noun: [シャーロッツビル], Cluster: 3
# Noun: 熾, Cluster: 7
# Noun: [ジェフ・ジャレット], Cluster: 3
# Noun: 凡人, Cluster: 7
# Noun: [ガードレール], Cluster: 5
# Noun: ヒッチハイク, Cluster: 3
# Noun: 小分け, Cluster: 0
# Noun: 遺訓, Cluster: 7
# Noun: [ジャック・ニコルソン], Cluster: 6
# Noun: 交流協会, Cluster: 8
# Processing batch 104...
# Noun: 忘年会, Cluster: 6
# Noun: [戦力], Cluster: 8
# Noun: [ウェストミンスター宮殿], Cluster: 5
# Noun: [SCANDAL_(日本のバンド)], Cluster: 6
# Noun: [パーミャチ・アゾーヴァ], Cluster: 7
# Noun: [ザ・デストロイヤー], Cluster: 2
# Noun: [エイベックス・ピクチャーズ], Cluster: 6
# Noun: [自動車保険], Cluster: 9
# Noun: [サムエル記], Cluster: 0
# Noun: [空飛ぶ円盤], Cluster: 7
# Processing batch 106...
# Noun: [テトロドトキシン], Cluster: 6
# Noun: [雨傘番組], Cluster: 7
# Noun: 夜会, Cluster: 7
# Noun: [諜報], Cluster: 8
# Noun: [自動案内軌条式旅客輸送システム], Cluster: 9
# Noun: は株, Cluster: 9
# Noun: [ブワイフ朝], Cluster: 0
# Noun: グレイホーク, Cluster: 8
# Noun: 剃刀, Cluster: 2
# Noun: [ヘメーンテ], Cluster: 8
# Processing batch 108...
# Noun: 中学受験, Cluster: 5
# Noun: [諫早駅], Cluster: 5
# Noun: 間断, Cluster: 3
# Noun: [管仲], Cluster: 7
# Noun: [史書], Cluster: 7
# Noun: [トップウェスト], Cluster: 3
# Noun: 大衆紙, Cluster: 8
# Noun: [ドイツのための選択肢], Cluster: 8
# Noun: [ウィリアム・アフィルス], Cluster: 3
# Noun: [ガレリウス], Cluster: 8
# Processing batch 110...
# Noun: [東日本旅客鉄道仙台支社], Cluster: 4
# Noun: [電磁相互作用], Cluster: 3
# Noun: [横綱審議委員会], Cluster: 0
# Noun: [簡文帝_(南朝梁)], Cluster: 1
# Noun: 秤, Cluster: 7
# Noun: [出版取次], Cluster: 4
# Noun: [田中義一内閣], Cluster: 0
# Noun: [公衆交換電話網], Cluster: 4
# Noun: [キビ], Cluster: 7
# Noun: [公理的集合論], Cluster: 3
# Processing batch 111...
# Noun: 女王様, Cluster: 0
# Noun: [京滋バイパス], Cluster: 7
# Noun: 烈士, Cluster: 4
# Noun: 欲情, Cluster: 0
# Noun: [剣道の段級位制], Cluster: 3
# Noun: [トレオニン], Cluster: 2
# Noun: [フィリピン海], Cluster: 7
# Noun: [バート・エーンハウゼン], Cluster: 7
# Noun: 中期経営計画, Cluster: 1
# Noun: [毛髪], Cluster: 2
# Processing batch 113...
# Noun: 華厳, Cluster: 4
# Noun: [リボース], Cluster: 7
# Noun: [札幌市営地下鉄東豊線], Cluster: 2
# Noun: きゃく, Cluster: 3
# Noun: [ロータスグループ], Cluster: 5
# Noun: [デンゼル・ワシントン], Cluster: 5
# Noun: スカパー!, Cluster: 5
# Noun: 赤身, Cluster: 3
# Noun: 偶像崇拝, Cluster: 1
# Noun: [エルナン・コルテス], Cluster: 6
# Processing batch 115...
# Noun: [ヴァランシエンヌ], Cluster: 4
# Noun: [高須藩], Cluster: 9
# Noun: [SRB-A], Cluster: 2
# Noun: [秋霜_(駆逐艦)], Cluster: 4
# Noun: [好熱菌], Cluster: 1
# Noun: [フォアリバー造船所], Cluster: 4
# Noun: [第二次ブルランの戦い], Cluster: 4
# Noun: [シーライオン], Cluster: 4
# Noun: [水和], Cluster: 1
# Noun: [連邦主義], Cluster: 7
# Processing batch 117...
# Noun: [テバイ], Cluster: 6
# Noun: [イデアル_(環論)], Cluster: 5
# Noun: [光明天皇], Cluster: 6
# Noun: 舞楽, Cluster: 2
# Noun: [黄海海戦_(日露戦争)], Cluster: 6
# Noun: [サイクロトロン], Cluster: 8
# Noun: [第14回参議院議員通常選挙], Cluster: 9
# Noun: [エディ・アーバイン], Cluster: 1
# Noun: [最多セーブ投手_(日本プロ野球)], Cluster: 1
# Noun: 入鹿, Cluster: 2
# Processing batch 119...
# Noun: 棋界, Cluster: 6
# Noun: [オーデル・ナイセ線], Cluster: 5
# Noun: [日本犬], Cluster: 7
# Noun: [不動産鑑定士], Cluster: 4
# Noun: [溝], Cluster: 7
# Noun: 綿織物, Cluster: 7
# Noun: [チェシン公国], Cluster: 5
# Noun: [ロシア連邦の地方区分], Cluster: 5
# Noun: 防衛大臣, Cluster: 3
# Noun: [ラザフォード・ヘイズ], Cluster: 3
# Processing batch 120...
# Noun: [Su-25_(航空機)], Cluster: 6
# Noun: 税理士, Cluster: 7
# Noun: [鹿児島県庁], Cluster: 7
# Noun: [タイコンデロガ級ミサイル巡洋艦], Cluster: 6
# Noun: [八百屋], Cluster: 3
# Noun: [企画ネット番組], Cluster: 3
# Noun: [鼻濁音], Cluster: 2
# Noun: 船艙, Cluster: 1
# Noun: [大井_(軽巡洋艦)], Cluster: 3
# Noun: [燃料タンク], Cluster: 6
# Processing batch 122...
# Noun: [ゲプハルト・レベレヒト・フォン・ブリュッヘル], Cluster: 8
# Noun: [天神真楊流], Cluster: 1
# Noun: アップタウン, Cluster: 9
# Noun: k2, Cluster: 7
# Noun: [微惑星], Cluster: 4
# Noun: 一眼レフカメラ, Cluster: 7
# Noun: [琺瑯], Cluster: 0
# Noun: 激震, Cluster: 5
# Noun: [果糖], Cluster: 4
# Noun: [アルモリカ], Cluster: 8
# Processing batch 124...
# Noun: [皮膚病], Cluster: 4
# Noun: ガス交換, Cluster: 4
# Noun: [グラスノスチ], Cluster: 6
# Noun: 制服組, Cluster: 5
# Noun: [バドワイザー], Cluster: 7
# Noun: [サッカーインドネシア代表], Cluster: 2
# Noun: [シビル・ユニオン], Cluster: 6
# Noun: 零細企業, Cluster: 6
# Noun: [欧州原子力共同体], Cluster: 6
# Noun: PSO2, Cluster: 7
# Processing batch 126...
# Noun: [Cheese!], Cluster: 0
# Noun: [畝], Cluster: 2
# Noun: 柚子, Cluster: 2
# Noun: 子孫繁栄, Cluster: 9
# Noun: 伝熱, Cluster: 8
# Noun: 個体変異, Cluster: 2
# Noun: 街の名前, Cluster: 3
# Noun: 転石, Cluster: 2
# Noun: 養蜂, Cluster: 2
# Noun: [ルー_(食品)], Cluster: 2
# Processing batch 128...
# Noun: 土木科, Cluster: 8
# Noun: 魏志, Cluster: 1
# Noun: [西日本旅客鉄道金沢支社], Cluster: 3
# Noun: [ドゥッラーニー朝], Cluster: 2
# Noun: [T-1000], Cluster: 5
# Noun: [フェイズシフト装甲], Cluster: 5
# Noun: [林家三平_(初代)], Cluster: 6
# Noun: [ベルヌーイ数], Cluster: 9
# Noun: [クロダイ], Cluster: 9
# Noun: 家庭教育, Cluster: 8
# Processing batch 130...
# Noun: [ジャック・ラカン], Cluster: 1
# Noun: [DDT_(プロレス技)], Cluster: 2
# Noun: [紀伝体], Cluster: 9
# Noun: [教科用図書検定], Cluster: 0
# Noun: [グリゴリー・ラスプーチン], Cluster: 8
# Noun: 合い言葉, Cluster: 6
# Noun: 壮烈, Cluster: 6
# Noun: [第7回AAAアジア野球選手権大会日本代表], Cluster: 2
# Noun: [フラ・アンジェリコ], Cluster: 8
# Noun: 安土桃山時代, Cluster: 9
# Processing batch 131...
# Noun: 万年筆, Cluster: 8
# Noun: [擬洋風建築], Cluster: 2
# Noun: 外交委員会, Cluster: 6
# Noun: [キューブ], Cluster: 3
# Noun: [禄], Cluster: 0
# Noun: [アシュビル_(ノースカロライナ州)], Cluster: 1
# Noun: [JCB], Cluster: 3
# Noun: [連合軍軍政期_(朝鮮史)], Cluster: 1
# Noun: [近代経済学], Cluster: 2
# Noun: [護憲三派], Cluster: 6
# Processing batch 133...
# Noun: 債権回収, Cluster: 6
# Noun: [Streaming_SIMD_Extensions], Cluster: 1
# Noun: [自由民主党副総裁], Cluster: 6
# Noun: [ゆうゆう窓口], Cluster: 6
# Noun: [グアルディア・シビル], Cluster: 4
# Noun: [ニコライ・カサートキン], Cluster: 4
# Noun: 同性カップル, Cluster: 6
# Noun: 芸能ニュース, Cluster: 5
# Noun: [1992年のNFL], Cluster: 9
# Noun: [国境線], Cluster: 4
# Processing batch 135...
# Noun: [第2次橋本内閣], Cluster: 7
# Noun: [無声声門摩擦音], Cluster: 4
# Noun: [Category:明王], Cluster: 8
# Noun: [神戸連続児童殺傷事件], Cluster: 7
# Noun: [人妻], Cluster: 0
# Noun: 地域資源, Cluster: 5
# Noun: [農地法], Cluster: 7
# Noun: フルバック, Cluster: 3
# Noun: [なかよしラブリー], Cluster: 0
# Noun: [墨_(書道雑誌)], Cluster: 8
# Processing batch 137...
# Noun: 成人向け漫画, Cluster: 8
# Noun: 現代医学, Cluster: 0
# Noun: 平話, Cluster: 7
# Noun: [多重化], Cluster: 5
# Noun: [鈴与], Cluster: 8
# Noun: [杉原紙], Cluster: 7
# Noun: パーネル, Cluster: 6
# Noun: [トム・ゲーレルス], Cluster: 2
# Noun: [結膜炎], Cluster: 0
# Noun: [ビンディング], Cluster: 5
# Processing batch 139...
# Noun: [孔子廟], Cluster: 1
# Noun: [ヘラブナ], Cluster: 9
# Noun: [地球楕円体], Cluster: 8
# Noun: [アスパラギン], Cluster: 9
# Noun: [PYG], Cluster: 2
# Noun: [実行ユニット], Cluster: 8
# Noun: [シャフト], Cluster: 8
# Noun: [フランス第二共和政], Cluster: 7
# Noun: [後生動物], Cluster: 9
# Noun: ワカメ, Cluster: 1
# Processing batch 140...
# Noun: [自由律俳句], Cluster: 6
# Noun: [裏ビデオ], Cluster: 4
# Noun: [ヴィクトリアズ・シークレット], Cluster: 4
# Noun: じたい, Cluster: 6
# Noun: [私娼], Cluster: 6
# Noun: [せん馬], Cluster: 9
# Noun: [DJ_OZMA], Cluster: 4
# Noun: [ウィジェット], Cluster: 1
# Noun: [回腸], Cluster: 3
# Noun: [1998年の映画], Cluster: 4
# Processing batch 142...
# Noun: [クルーザー], Cluster: 5
# Noun: [トヨタ・ソアラ], Cluster: 0
# Noun: [カード_(食品)], Cluster: 2
# Noun: 音沙汰, Cluster: 4
# Noun: 筆画, Cluster: 2
# Noun: [新貨条例], Cluster: 6
# Noun: [軍隊の階級], Cluster: 5
# Noun: 朋友, Cluster: 1
# Noun: 小泉政権, Cluster: 5
# Noun: [実録シリーズ], Cluster: 7
# Processing batch 144...
# Noun: [背骨], Cluster: 8
# Noun: B級映画, Cluster: 1
# Noun: [ロングアイランド・ダックス], Cluster: 9
# Noun: [比例中国ブロック], Cluster: 9
# Noun: [ベトナムに平和を!市民連合], Cluster: 1
# Noun: 河尻, Cluster: 2
# Noun: [水銀灯], Cluster: 8
# Noun: ラズベリー, Cluster: 1
# Noun: トップニュース, Cluster: 6
# Noun: 天元, Cluster: 2
# Processing batch 146...
# Noun: [専修大学硬式野球部], Cluster: 9
# Noun: 会員カード, Cluster: 8
# Noun: [敦明親王], Cluster: 2
# Noun: [至聖三者], Cluster: 3
# Noun: [ドラゴン・キッド], Cluster: 9
# Noun: [カリフラワー], Cluster: 4
# Noun: 150形, Cluster: 6
# Noun: [NHK山形放送局], Cluster: 1
# Noun: [第五共和国_(大韓民国)], Cluster: 1
# Noun: 地域再生, Cluster: 1
# Processing batch 148...
# Noun: [未来_(短歌結社)], Cluster: 6
# Noun: [ムラト2世], Cluster: 7
# Noun: 絶対王政, Cluster: 4
# Noun: 北の富士, Cluster: 1
# Noun: [沿岸漁業], Cluster: 2
# Noun: [コードレス電話], Cluster: 8
# Noun: [ルピア], Cluster: 8
# Noun: [May_J.], Cluster: 3
# Noun: [ダフト・パンク], Cluster: 3
# Noun: [ポリシー], Cluster: 8
# Processing batch 149...
# Noun: 射的, Cluster: 1
# Noun: 板目, Cluster: 1
# Noun: [マリンスポーツ], Cluster: 1
# Noun: [コロンバンガラ島沖海戦], Cluster: 6
# Noun: 町並み保存, Cluster: 0
# Noun: [サンタクルーズ_(カリフォルニア州)], Cluster: 2
# Noun: [ドーパント], Cluster: 4
# Noun: [ウィリアムズ大学], Cluster: 2
# Noun: [ガジュマル], Cluster: 1
# Noun: [フラクトゥール], Cluster: 3
# Processing batch 151...
# Noun: [楡林港], Cluster: 6
# Noun: 部落差別, Cluster: 8
# Noun: 農業振興, Cluster: 8
# Noun: 茶番, Cluster: 4
# Noun: 興福, Cluster: 1
# Noun: [旧制中学], Cluster: 8
# Noun: [ペイシストラトス], Cluster: 1
# Noun: [非ユークリッド幾何学], Cluster: 3
# Noun: 風紀委員, Cluster: 4
# Noun: 身頃, Cluster: 3
# Processing batch 153...
# Noun: [摂津名所図会], Cluster: 5
# Noun: [レニー・クラヴィッツ], Cluster: 1
# Noun: [潮州語], Cluster: 0
# Noun: [UEFAヨーロッパリーグ_2013-14], Cluster: 2
# Noun: [槇_(松型駆逐艦)], Cluster: 8
# Noun: [月刊サンデージェネックス], Cluster: 8
# Noun: ゴセイジャー, Cluster: 8
# Noun: 岩室, Cluster: 5
# Noun: [観測可能な宇宙], Cluster: 4
# Noun: あやかし, Cluster: 8
# Processing batch 155...
# Noun: ロケハン, Cluster: 1
# Noun: 神経内科, Cluster: 4
# Noun: [セキュリティポリス], Cluster: 3
# Noun: 最果て, Cluster: 5
# Noun: [鉄骨鉄筋コンクリート構造], Cluster: 7
# Noun: 汗国, Cluster: 6
# Noun: [アルピナ], Cluster: 2
# Noun: チョッパ制御, Cluster: 2
# Noun: 封建時代, Cluster: 5
# Noun: [カナダ政府], Cluster: 8
# Processing batch 157...
# Noun: 可動橋, Cluster: 7
# Noun: プロダクトデザイン, Cluster: 8
# Noun: [外孫], Cluster: 9
# Noun: 理科教育, Cluster: 4
# Noun: [ジャハーンダール・シャー], Cluster: 2
# Noun: 律速, Cluster: 3
# Noun: [埼玉県知事], Cluster: 4
# Noun: [水酸化アルミニウム], Cluster: 3
# Noun: 満貫, Cluster: 6
# Noun: 経験主義, Cluster: 6
# Processing batch 158...
# Noun: [学位論文], Cluster: 0
# Noun: 100円ショップ, Cluster: 3
# Noun: [女性ホルモン], Cluster: 9
# Noun: [ロイヤル・メダル], Cluster: 0
# Noun: [商人_(商法)], Cluster: 7
# Noun: 太田プロ, Cluster: 6
# Noun: [ゼンパー・オーパー], Cluster: 0
# Noun: [雲海], Cluster: 9
# Noun: 一刀流, Cluster: 8
# Noun: [企業博物館], Cluster: 3
# Processing batch 160...
# Noun: [絶滅のおそれのある野生動植物の種の保存に関する法律], Cluster: 1
# Noun: [キリスト教原理主義], Cluster: 1
# Noun: 行動主義, Cluster: 1
# Noun: 尊攘, Cluster: 1
# Noun: [ウォレアイ環礁], Cluster: 6
# Noun: [エレクトリック・ライト・オーケストラ], Cluster: 2
# Noun: [こけら落とし], Cluster: 6
# Noun: [システィーナ礼拝堂天井画], Cluster: 7
# Noun: [ガズニー], Cluster: 3
# Noun: [#貴族], Cluster: 1
# Processing batch 162...
# Noun: [葉緑素], Cluster: 5
# Noun: 外交部長, Cluster: 0
# Noun: [タウソン], Cluster: 1
# Noun: [アドベント], Cluster: 7
# Noun: [下剤], Cluster: 3
# Noun: [明星中学校・高等学校_(大阪府)], Cluster: 1
# Noun: ちまた, Cluster: 7
# Noun: [VVVフェンロー], Cluster: 1
# Noun: [Mnet], Cluster: 2
# Noun: 天辺, Cluster: 7
# Processing batch 164...
# Noun: [Unity], Cluster: 0
# Noun: [サクラスターオー], Cluster: 2
# Noun: コーヒーカップ, Cluster: 0
# Noun: 覇道, Cluster: 6
# Noun: [日曜日から始まる閏年], Cluster: 8
# Noun: [ロータリー車], Cluster: 0
# Noun: 文明圏, Cluster: 7
# Noun: [サン・キュロット], Cluster: 7
# Noun: [ストロー級], Cluster: 2
# Noun: [アレンタウン], Cluster: 1
# Processing batch 165...
# Noun: [北京オリンピックにおけるボクシング競技], Cluster: 3
# Noun: [腹腔鏡], Cluster: 2
# Noun: 前鋒, Cluster: 4
# Noun: [愛知大学野球連盟], Cluster: 3
# Noun: ダイオキシン, Cluster: 2
# Noun: [天野ひろゆき], Cluster: 9
# Noun: 情報教育, Cluster: 8
# Noun: [国鉄213系電車], Cluster: 6
# Noun: [コール・ポーター], Cluster: 9
# Noun: 東京郊外, Cluster: 7
# Processing batch 167...
# Noun: [一般意味論], Cluster: 7
# Noun: [建業], Cluster: 2
# Noun: [アイガモ], Cluster: 6
# Noun: 構造計算, Cluster: 5
# Noun: [ルートヴィヒ・アンドレアス・フォイエルバッハ], Cluster: 7
# Noun: [旗本退屈男], Cluster: 9
# Noun: [皇朝十二銭], Cluster: 6
# Noun: [アンフィポリス], Cluster: 8
# Noun: [第一三共ヘルスケア], Cluster: 3
# Noun: [魔神英雄伝ワタル], Cluster: 9
# Processing batch 169...
# Noun: [A-6_(航空機)], Cluster: 1
# Noun: [ルンガ沖夜戦], Cluster: 4
# Noun: [敦康親王], Cluster: 6
# Noun: [ホイスト], Cluster: 8
# Noun: [超硬合金], Cluster: 0
# Noun: [シャーロット・ブロンテ], Cluster: 4
# Noun: [神祇伯], Cluster: 6
# Noun: [アフターマーケット], Cluster: 0
# Noun: [サザン鉄道_(アメリカ)], Cluster: 9
# Noun: 礼金, Cluster: 2
# Processing batch 171...
# Noun: [エロ本], Cluster: 9
# Noun: [三迫ボクシングジム], Cluster: 1
# Noun: [マリア_(ハヤテのごとく!)], Cluster: 7
# Noun: [wikt:ja:一], Cluster: 7
# Noun: [アンソニア], Cluster: 5
# Noun: [コンボ_(ゲーム)], Cluster: 8
# Noun: [ボディビルダー], Cluster: 9
# Noun: [江戸重長], Cluster: 2
# Noun: [メキシコグランプリ], Cluster: 1
# Noun: 分かれ目, Cluster: 7
# Processing batch 173...
# Noun: [セントラル・パシフィック鉄道], Cluster: 0
# Noun: [葦原中国平定], Cluster: 8
# Noun: [神田伯山], Cluster: 9
# Noun: [ジミー・バリアント], Cluster: 5
# Noun: 古紙, Cluster: 2
# Noun: [RD-180], Cluster: 6
# Noun: [CANDU炉], Cluster: 6
# Noun: [jubeat], Cluster: 9
# Noun: 酒肴, Cluster: 2
# Noun: [ハンス・ジマー], Cluster: 1
# Processing batch 174...
# Noun: [永代通り], Cluster: 0
# Noun: [露地], Cluster: 7
# Noun: 別業, Cluster: 8
# Noun: [ハル・ベリー], Cluster: 2
# Noun: [日本の侵略的外来種ワースト100], Cluster: 6
# Noun: スピードスケート, Cluster: 2
# Noun: [リッペ侯国], Cluster: 3
# Noun: [大江戸捜査網], Cluster: 9
# Noun: [オルテニア], Cluster: 3
# Noun: [フレネルレンズ], Cluster: 4
# Processing batch 176...
# Noun: [東京バレエ団], Cluster: 9
# Noun: [慶尚南道_(日本統治時代)], Cluster: 8
# Noun: [アンソニー・ウェイン], Cluster: 2
# Noun: [婦人科学], Cluster: 8
# Noun: [延長_(日本の道路)], Cluster: 4
# Noun: [鼠小僧], Cluster: 7
# Noun: [おかっぱ], Cluster: 1
# Noun: [土木工事], Cluster: 1
# Noun: [スパインファーム・レコード], Cluster: 9
# Noun: [進歩新党], Cluster: 8
# Processing batch 178...
# Noun: 数表示, Cluster: 6
# Noun: [キキョウ], Cluster: 3
# Noun: [ホヴァルツヴェルケ＝ドイツ造船], Cluster: 6
# Noun: [救難艇], Cluster: 6
# Noun: [蜂須賀至鎮], Cluster: 7
# Noun: [ロールス・ロイス_トレント], Cluster: 6
# Noun: [モーリハイ], Cluster: 0
# Noun: [007_カジノ・ロワイヤル], Cluster: 2
# Noun: [要港部], Cluster: 6
# Noun: [ナフプリオ], Cluster: 1
# Processing batch 180...
# Noun: [エデッサ伯国], Cluster: 8
# Noun: 上卿, Cluster: 1
# Noun: 軍事転用, Cluster: 3
# Noun: [デフトーンズ], Cluster: 7
# Noun: リレーション, Cluster: 7
# Noun: 評定衆, Cluster: 1
# Noun: 気位, Cluster: 6
# Noun: 小党, Cluster: 4
# Noun: ガス灯, Cluster: 6
# Noun: [萩の乱], Cluster: 1
# Processing batch 181...
# Noun: [ポンチキ], Cluster: 3
# Noun: ハイビスカス, Cluster: 7
# Noun: [自己批判], Cluster: 0
# Noun: アウトリーチ, Cluster: 1
# Noun: [細胞培養], Cluster: 2
# Noun: [黒羽織党], Cluster: 4
# Noun: 推論規則, Cluster: 0
# Noun: ホタテ, Cluster: 2
# Noun: [スタイナー・ブラザーズ], Cluster: 1
# Noun: [ペスカーラ県], Cluster: 1
# Processing batch 183...
# Noun: セイリング, Cluster: 2
# Noun: [ランボード], Cluster: 0
# Noun: 思想犯, Cluster: 7
# Noun: 学割, Cluster: 2
# Noun: 民用, Cluster: 5
# Noun: 昼ドラ, Cluster: 2
# Noun: [ジャック・シェパード_(LOST)], Cluster: 2
# Noun: [農林水産大臣政務官], Cluster: 7
# Noun: [チリ大学], Cluster: 7
# Noun: [国道329号], Cluster: 1
# Processing batch 185...
# Noun: [軍人勅諭], Cluster: 3
# Noun: [賭場], Cluster: 1
# Noun: 特快, Cluster: 5
# Noun: [ギミア・ぶれいく], Cluster: 5
# Noun: [南日本], Cluster: 7
# Noun: 番兵, Cluster: 8
# Noun: テロ集団, Cluster: 8
# Noun: [北海道札幌東高等学校], Cluster: 2
# Noun: [復活_(コンピュータゲーム)], Cluster: 8
# Noun: いかづち, Cluster: 1
# Processing batch 187...
# Noun: [有機体], Cluster: 6
# Noun: [安土町地域自治区], Cluster: 3
# Noun: [準中距離弾道ミサイル], Cluster: 1
# Noun: [ソンツェン・ガンポ], Cluster: 5
# Noun: [UAZ], Cluster: 4
# Noun: [天満天神繁昌亭], Cluster: 7
# Noun: オーストラリア政府, Cluster: 1
# Noun: [スヴェン・ヘディン], Cluster: 1
# Noun: キーチェーン, Cluster: 4
# Noun: [戦国策], Cluster: 7
# Processing batch 189...
# Noun: [推力重量比], Cluster: 4
# Noun: [痛覚], Cluster: 6
# Noun: [スタージ], Cluster: 2
# Noun: [東ティモールの首相], Cluster: 8
# Noun: [エイジアプロモーション], Cluster: 7
# Noun: [西山牧場], Cluster: 3
# Noun: [デイヴィッド・リヴィングストン], Cluster: 8
# Noun: 欲張り, Cluster: 2
# Noun: [RPL], Cluster: 4
# Noun: カラオケボックス, Cluster: 9
# Processing batch 191...
# Noun: [マニラ・ベイ], Cluster: 2
# Noun: [男系], Cluster: 8
# Noun: 算用数字, Cluster: 6
# Noun: [営団500形電車], Cluster: 0
# Noun: [歌謡浪曲], Cluster: 4
# Noun: [ボスニア・ヘルツェゴヴィナ], Cluster: 2
# Noun: [レチナ], Cluster: 0
# Noun: [区画整理事業], Cluster: 1
# Noun: [擬似戦争], Cluster: 2
# Noun: [ロングアイランドの戦い], Cluster: 2
# Processing batch 192...
# Noun: 埋蔵文化財センター, Cluster: 4
# Noun: [任那日本府], Cluster: 2
# Noun: [真空期待値], Cluster: 7
# Noun: [既製服], Cluster: 8
# Noun: 神文, Cluster: 2
# Noun: [セリー・オーク], Cluster: 3
# Noun: 上位概念, Cluster: 7
# Noun: [広沢真臣], Cluster: 2
# Noun: けんぎかい, Cluster: 0
# Noun: [イヴェコ], Cluster: 8
# Processing batch 194...
# Noun: [鍾路], Cluster: 2
# Noun: [インド連邦_(ドミニオン)], Cluster: 0
# Noun: [家庭裁判所調査官], Cluster: 8
# Noun: [四諦], Cluster: 1
# Noun: [カール・リープクネヒト], Cluster: 0
# Noun: 銘酒, Cluster: 6
# Noun: [レッチワース], Cluster: 0
# Noun: [HC_CSKAモスクワ], Cluster: 3
# Noun: エアリアル, Cluster: 9
# Noun: ソノシート, Cluster: 5
# Processing batch 196...
# Noun: 出師, Cluster: 2
# Noun: トライバル, Cluster: 6
# Noun: [イザベラ・バード], Cluster: 4
# Noun: [カタルーニャ自治州議会], Cluster: 2
# Noun: [平釜線], Cluster: 3
# Noun: 守旧, Cluster: 4
# Noun: [不平等], Cluster: 5
# Noun: [法務博士], Cluster: 4
# Noun: [#農民], Cluster: 4
# Noun: [行列要素], Cluster: 5
# Processing batch 198...
# Noun: [超実数], Cluster: 5
# Noun: [法師], Cluster: 0
# Noun: [ノーバート・ウィーナー], Cluster: 5
# Noun: [三都主アレサンドロ], Cluster: 4
# Noun: [リオ・ファーディナンド], Cluster: 7
# Noun: [DOES], Cluster: 7
# Noun: スパルタ教育, Cluster: 7
# Noun: [オルロ], Cluster: 1
# Noun: 松ヶ丘, Cluster: 6
# Noun: [氷点], Cluster: 3
# Processing batch 199...
# Noun: かくし芸, Cluster: 2
# Noun: [鉄道模型趣味], Cluster: 2
# Noun: 史料批判, Cluster: 6
# Noun: [キリンレモン], Cluster: 2
# Noun: 被害者の会, Cluster: 4
# Noun: [日本の学校給食], Cluster: 1
# Noun: 閉集合, Cluster: 6
# Noun: [金ヶ崎の戦い], Cluster: 5
# Noun: 国公立大, Cluster: 3
# Noun: [毒薬], Cluster: 1
# Processing batch 201...
# Noun: [アルフレート・ヨードル], Cluster: 4
# Noun: [転校生], Cluster: 8
# Noun: [下地中分], Cluster: 3
# Noun: 朝刊紙, Cluster: 4
# Noun: [バンダイナムコホールディングス], Cluster: 4
# Noun: 脳損傷, Cluster: 6
# Noun: [レーティング], Cluster: 4
# Noun: [歩脚], Cluster: 6
# Noun: [御典医], Cluster: 3
# Noun: [ドローソフト], Cluster: 0
# Processing batch 203...
# Noun: [磐城郡], Cluster: 9
# Noun: [鹿野城], Cluster: 9
# Noun: [東京地検], Cluster: 4
# Noun: [山形空港], Cluster: 4
# Noun: [ロマンティック街道], Cluster: 3
# Noun: [穆宗_(遼)], Cluster: 9
# Noun: [近畿大学附属高等学校・中学校], Cluster: 8
# Noun: [檜枝岐村], Cluster: 4
# Noun: [ハミルトン公爵], Cluster: 2
# Noun: [得点圏打率], Cluster: 1
# Processing batch 205...
# Noun: [サント・ドミンゴ], Cluster: 8
# Noun: [海軍少佐], Cluster: 9
# Noun: [ファジィ論理], Cluster: 4
# Noun: 延平, Cluster: 0
# Noun: [プトレマイオス3世], Cluster: 0
# Noun: [等比数列], Cluster: 4
# Noun: [2004年のNBAドラフト], Cluster: 2
# Noun: [国際バカロレア資格], Cluster: 9
# Noun: [数値計算], Cluster: 5
# Noun: [ブアカーオ・ポー.プラムック], Cluster: 2
# Processing batch 206...
# Noun: [ヴラド・ツェペシュ], Cluster: 0
# Noun: パブリックコメント, Cluster: 7
# Noun: [職業病], Cluster: 9
# Noun: [笑う犬], Cluster: 1
# Noun: あかちゃん, Cluster: 1
# Noun: [ウイニング競馬], Cluster: 1
# Noun: [源氏物語における写本記号], Cluster: 0
# Noun: [宅見組], Cluster: 2
# Noun: [minori], Cluster: 1
# Noun: [シャトレーゼ], Cluster: 6
# Processing batch 208...
# Noun: [たかじん胸いっぱい], Cluster: 3
# Noun: 使用済み核燃料, Cluster: 2
# Noun: [甲斐姫], Cluster: 4
# Noun: [イトマン事件], Cluster: 0
# Noun: [栄養繁殖], Cluster: 2
# Noun: [SET_UP!!], Cluster: 3
# Noun: [相鉄グループ], Cluster: 1
# Noun: [ウルトラマンゼアス], Cluster: 3
# Noun: [組み込みオペレーティングシステム], Cluster: 7
# Noun: [シーホース三河], Cluster: 6
# Processing batch 210...
# Noun: [電力量計], Cluster: 4
# Noun: [サテライトキャンパス], Cluster: 4
# Noun: [望], Cluster: 0
# Noun: [経営戦略論], Cluster: 4
# Noun: [フランチェスコ会], Cluster: 5
# Noun: [カッコーの巣の上で], Cluster: 7
# Noun: [世界の艦船], Cluster: 7
# Noun: そうりゅう, Cluster: 3
# Noun: 立方晶, Cluster: 0
# Noun: [初期化ベクトル], Cluster: 4
# Processing batch 212...
# Noun: [リリーナ・ドーリアン], Cluster: 0
# Noun: [ザ・テンプターズ], Cluster: 6
# Noun: 因数分解, Cluster: 1
# Noun: [パラス_(小惑星)], Cluster: 5
# Noun: [シニヨン], Cluster: 0
# Noun: [De-LAX], Cluster: 6
# Noun: [ヒグラシ], Cluster: 2
# Noun: [フィリップス・エクセター・アカデミー], Cluster: 5
# Noun: [SKF], Cluster: 9
# Noun: [モリスコ追放], Cluster: 5
# Processing batch 213...
# Noun: ニヒリズム, Cluster: 6
# Noun: [工業大学], Cluster: 0
# Noun: [桐生競艇場], Cluster: 1
# Noun: [鏡像異性体], Cluster: 8
# Noun: [御林], Cluster: 6
# Noun: [ガウス関数], Cluster: 8
# Noun: 穴蔵, Cluster: 3
# Noun: [☆Taku_Takahashi], Cluster: 5
# Noun: おむすび, Cluster: 3
# Noun: [結合次数], Cluster: 8
# Processing batch 215...
# Noun: 太陽の下, Cluster: 0
# Noun: 水生昆虫, Cluster: 2
# Noun: [IC], Cluster: 9
# Noun: [イヴァン・マラドイ], Cluster: 7
# Noun: [ザゼンソウ], Cluster: 2
# Noun: マイルーム, Cluster: 5
# Noun: [新株予約権付社債], Cluster: 5
# Noun: [#総督一覧], Cluster: 5
# Noun: [張敖], Cluster: 7
# Noun: [ゲスの極み乙女。], Cluster: 4
# Processing batch 217...
# Noun: 天狼, Cluster: 3
# Noun: [七堂伽藍], Cluster: 8
# Noun: [アラン・ホールズワース], Cluster: 1
# Noun: [世], Cluster: 4
# Noun: イサキオス, Cluster: 6
# Noun: [太陽活動], Cluster: 9
# Noun: 薬物動態, Cluster: 9
# Noun: [早稲田大学文学部], Cluster: 4
# Noun: [アメリカ合衆国の州歌], Cluster: 2
# Noun: [中国標準時], Cluster: 6
# Processing batch 219...
# Noun: [シュトルツェナウ], Cluster: 1
# Noun: [因果応報], Cluster: 5
# Noun: [修羅の門], Cluster: 0
# Noun: [スペース・ゼロ], Cluster: 0
# Noun: [済陰郡], Cluster: 8
# Noun: [ブリッジポート], Cluster: 4
# Noun: [トレインチャンネル], Cluster: 6
# Noun: [武蔵陵墓地], Cluster: 8
# Noun: [Category:シベリア鉄道], Cluster: 4
# Noun: [キューバの国家元首], Cluster: 9
# Processing batch 220...
# Noun: ファーストコンタクト, Cluster: 1
# Noun: [最小可聴値], Cluster: 9
# Noun: 信号灯, Cluster: 6
# Noun: 幕政改革, Cluster: 2
# Noun: [走り幅跳び], Cluster: 5
# Noun: [タックル_(フットボール)], Cluster: 5
# Noun: [永暦帝], Cluster: 0
# Noun: [エル・アル航空], Cluster: 6
# Noun: [トウジンビエ], Cluster: 7
# Noun: [物理現象], Cluster: 9
# Processing batch 222...
# Noun: [さきたま杯], Cluster: 3
# Noun: [ハンス・ホルバイン], Cluster: 5
# Noun: [スーペルクラシコ], Cluster: 3
# Noun: 起毛, Cluster: 8
# Noun: [長門探題], Cluster: 5
# Noun: [コンドロイチン硫酸], Cluster: 9
# Noun: [推奨ブラウザ], Cluster: 1
# Noun: エロい, Cluster: 8
# Noun: [ベルリン＝ブランデンブルク＝シュレージシェ・オーバーラウジッツ福音主義教会], Cluster: 2
# Noun: [ストリートファイターEX], Cluster: 7
# Processing batch 224...
# Noun: [かんぴょう], Cluster: 2
# Noun: [ギニュー特戦隊], Cluster: 3
# Noun: [小石川植物園], Cluster: 7
# Noun: [重力異常], Cluster: 8
# Noun: [カッツェネルンボーゲン伯], Cluster: 9
# Noun: [洗衣院], Cluster: 9
# Noun: [ボロース], Cluster: 5
# Noun: [高度道路交通システム], Cluster: 4
# Noun: [Guarded_Horn_Clauses], Cluster: 8
# Noun: [タイロナ], Cluster: 9
# Processing batch 226...
# Noun: [Direct2D], Cluster: 1
# Noun: [国道127号], Cluster: 9
# Noun: [Adobe_Creative_Suite], Cluster: 1
# Noun: [TFF1.リグ], Cluster: 2
# Noun: [スウィングマン], Cluster: 2
# Noun: [水割り], Cluster: 5
# Noun: [MiNT], Cluster: 1
# Noun: [AFCユース選手権], Cluster: 2
# Noun: [哀歌], Cluster: 6
# Noun: 方術, Cluster: 7
# Processing batch 228...
# Noun: [アル・ガラファ], Cluster: 2
# Noun: [拉致問題対策本部], Cluster: 5
# Noun: 王法, Cluster: 4
# Noun: [麦屋節], Cluster: 4
# Noun: [鬼界ヶ島], Cluster: 7
# Noun: [牧谿], Cluster: 4
# Noun: [宇宙空母ギャラクティカ], Cluster: 8
# Noun: [スクラム_(ラグビー)], Cluster: 2
# Noun: [ブローニングBAR], Cluster: 1
# Noun: [湘南ベルマーレフットサルクラブ], Cluster: 2
# Processing batch 229...
# Noun: ヒルトップ, Cluster: 1
# Noun: [ハスラー], Cluster: 9
# Noun: [ドグラ・マグラ], Cluster: 9
# Noun: 産業振興センター, Cluster: 1
# Noun: [借入金], Cluster: 1
# Noun: [モルデFK], Cluster: 0
# Noun: [光市母子殺害事件], Cluster: 5
# Noun: ソープオペラ, Cluster: 9
# Noun: [コンチャーク], Cluster: 3
# Noun: [チベット大蔵経], Cluster: 7
# Processing batch 231...
# Noun: つうかい, Cluster: 5
# Noun: 国際科, Cluster: 4
# Noun: 肱, Cluster: 3
# Noun: [ハウスキーパー], Cluster: 1
# Noun: [中心極限定理], Cluster: 7
# Noun: [サプライサイド経済学], Cluster: 0
# Noun: [摩耶山丸], Cluster: 1
# Noun: フリートベルク, Cluster: 3
# Noun: [フィンランドグランプリ], Cluster: 8
# Noun: [軍艦行進曲], Cluster: 5
# Processing batch 233...
# Noun: [歴史法学], Cluster: 0
# Noun: [アーノルト], Cluster: 7
# Noun: [アダルト・コンテンポラリー], Cluster: 3
# Noun: [ムラト3世], Cluster: 4
# Noun: ナイマン, Cluster: 3
# Noun: [司法巡査], Cluster: 0
# Noun: [木更津キャッツアイ], Cluster: 1
# Noun: [不逮捕特権], Cluster: 0
# Noun: 博愛主義, Cluster: 0
# Noun: [ジョルジオ・モロダー], Cluster: 3
# Processing batch 235...
# Noun: ニュージャパン, Cluster: 2
# Noun: 名宛, Cluster: 0
# Noun: [カラシナ], Cluster: 1
# Noun: [カリガリ博士], Cluster: 6
# Noun: [メガロポリスのフィロポイメン], Cluster: 5
# Noun: [同人社], Cluster: 0
# Noun: [日本科学技術振興財団], Cluster: 8
# Noun: [北条鉄道], Cluster: 8
# Noun: [足守地域], Cluster: 8
# Noun: [京葉工業地域], Cluster: 8
# Processing batch 236...
# Noun: [函数等式], Cluster: 3
# Noun: [キン肉マンII世_超人聖戦史], Cluster: 2
# Noun: [人文科学研究科], Cluster: 5
# Noun: [SKET_DANCE], Cluster: 2
# Noun: [ジョン・ドライデン], Cluster: 5
# Noun: [アラスカ州知事], Cluster: 1
# Noun: [犬童一心], Cluster: 2
# Noun: [X線天文学], Cluster: 3
# Noun: [クリスチャン・クリエン], Cluster: 2
# Noun: 流亡, Cluster: 1
# Processing batch 238...
# Noun: [マルメディ], Cluster: 2
# Noun: [オラニエンブルク], Cluster: 2
# Noun: [ファビュラス・ムーラ], Cluster: 8
# Noun: [カラミティガンダム], Cluster: 0
# Noun: [バルチースク], Cluster: 2
# Noun: [ムスト], Cluster: 6
# Noun: [外務大臣_(フランス)], Cluster: 3
# Noun: [ウルトラマンキング], Cluster: 5
# Noun: [フナムシ], Cluster: 6
# Noun: おじょ, Cluster: 5
# Processing batch 240...
# Noun: r3, Cluster: 4
# Noun: [アミド結合], Cluster: 6
# Noun: [モーターボート競走法], Cluster: 5
# Noun: 麦わら帽子, Cluster: 9
# Noun: [グーンズ], Cluster: 5
# Noun: [夜間], Cluster: 5
# Noun: [イワン・プトスキー], Cluster: 8
# Noun: 正業, Cluster: 5
# Noun: 完パケ, Cluster: 8
# Noun: しんくう, Cluster: 6
# Processing batch 242...
# Noun: [シャコガイ], Cluster: 3
# Noun: [ダークナイト_ライジング], Cluster: 9
# Noun: といがわ, Cluster: 7
# Noun: [永昌大君], Cluster: 5
# Noun: キャラメルボックス, Cluster: 4
# Noun: [コールドケース_迷宮事件簿], Cluster: 9
# Noun: 小豆色, Cluster: 3
# Noun: [オート＝ピレネー県], Cluster: 6
# Noun: [電磁界], Cluster: 2
# Noun: [アニエス・ヴァルダ], Cluster: 4
# Processing batch 243...
# Noun: 景王, Cluster: 1
# Noun: ペブル, Cluster: 8
# Noun: [エスキモー・アレウト語族], Cluster: 5
# Noun: [国内神名帳], Cluster: 4
# Noun: [ミクラス_(ウルトラ怪獣)], Cluster: 8
# Noun: [王立バイエルン邦有鉄道], Cluster: 8
# Noun: [ベディヴィア], Cluster: 1
# Noun: [フアナ2世_(ナバラ女王)], Cluster: 1
# Noun: [オールド・イングリッシュ・ブルドッグ], Cluster: 3
# Noun: おうじま, Cluster: 7
# Processing batch 245...
# Noun: [三田学園中学校・高等学校], Cluster: 7
# Noun: [スイセン属], Cluster: 4
# Noun: [ジョージ・グレンヴィル], Cluster: 5
# Noun: モンゴル高原, Cluster: 3
# Noun: 現代社会学部, Cluster: 6
# Noun: [東アーザルバーイジャーン州], Cluster: 3
# Noun: [マーキュリー賞], Cluster: 7
# Noun: [白山大賞典], Cluster: 7
# Noun: アイヌ民族, Cluster: 6
# Noun: [督脈], Cluster: 2
# Processing batch 247...
# Noun: [法政大学トマホークス], Cluster: 8
# Noun: 公選法, Cluster: 7
# Noun: [ガルフストリームパーク競馬場], Cluster: 8
# Noun: [ドレクセル大学], Cluster: 7
# Noun: 無か, Cluster: 6
# Noun: [ヘンリー・モーガン], Cluster: 4
# Noun: [ブレーキブースター], Cluster: 2
# Noun: [刎橋], Cluster: 3
# Noun: 大聖人, Cluster: 3
# Noun: [エプソン_アクアパーク品川], Cluster: 8
# Processing batch 249...
# Noun: [ナヒヤーン家], Cluster: 1
# Noun: [アメリカ戦略軍], Cluster: 5
# Noun: [華軼], Cluster: 7
# Noun: [根岸孝旨], Cluster: 0
# Noun: [エドゥアール・ダラディエ], Cluster: 1
# Noun: [ゲーム会社], Cluster: 3
# Noun: [M249軽機関銃], Cluster: 3
# Noun: アジア外交, Cluster: 5
# Noun: [#草書], Cluster: 7
# Noun: [紙コップ], Cluster: 2
# Processing batch 250...
# Noun: [菅屋長頼], Cluster: 0
# Noun: [ジョン・コナリー], Cluster: 5
# Noun: [日本弁理士会], Cluster: 5
# Noun: [コー・ロイヤルカップ], Cluster: 6
# Noun: [アジュディミツオー], Cluster: 6
# Noun: [ヴェラロ], Cluster: 3
# Noun: [国道285号], Cluster: 2
# Noun: [ヨハン・ボーデ], Cluster: 8
# Noun: [SMプレイ], Cluster: 4
# Noun: [新宿警察署], Cluster: 5
# Processing batch 252...
# Noun: [ソマリアの首相], Cluster: 9
# Noun: [華興会], Cluster: 4
# Noun: 右翼的, Cluster: 4
# Noun: [ソーラーポンド], Cluster: 1
# Noun: [A-36], Cluster: 1
# Noun: [縮合], Cluster: 0
# Noun: [召命], Cluster: 4
# Noun: しまじろう, Cluster: 8
# Noun: [大阪歴史博物館], Cluster: 5
# Noun: [コソボ・メトヒヤ自治州_(1990年-1999年)], Cluster: 9
# Processing batch 254...
# Noun: [戦術爆撃], Cluster: 5
# Noun: [近鉄劇場], Cluster: 1
# Noun: [#メモリースティック_Duo], Cluster: 2
# Noun: [朝鮮総督府政務総監], Cluster: 5
# Noun: [セス・ローゲン], Cluster: 4
# Noun: [アナスタシウス1世], Cluster: 8
# Noun: 正副, Cluster: 5
# Noun: [戸塚ヨットスクール], Cluster: 5
# Noun: [ジョン・バチェラー], Cluster: 0
# Noun: [クリティアス], Cluster: 8
# Processing batch 256...
# Noun: [情報提供者], Cluster: 6
# Noun: [ヘラルド・オブ・アームズ], Cluster: 9
# Noun: [ジャンゴ・フェット], Cluster: 2
# Noun: [太原雪斎], Cluster: 8
# Noun: [口語短歌], Cluster: 2
# Noun: [BOD], Cluster: 3
# Noun: [地上げ屋], Cluster: 2
# Noun: [GABA受容体], Cluster: 6
# Noun: [ヴィケルスン], Cluster: 1
# Noun: [ラ・ロッシュ＝モーリス], Cluster: 8
# Processing batch 257...
# Noun: [スークース], Cluster: 9
# Noun: 第1号被保険者, Cluster: 3
# Noun: [情報工学科], Cluster: 9
# Noun: [十八銀行], Cluster: 6
# Noun: [ジョーンズ多項式], Cluster: 2
# Noun: [俳協演劇研究所], Cluster: 9
# Noun: おたま, Cluster: 5
# Noun: [イブン・アスィール], Cluster: 3
# Noun: [JFEスチール東日本製鉄所], Cluster: 6
# Noun: [スマートデバイス], Cluster: 2
# Processing batch 259...
# Noun: [水交会], Cluster: 3
# Noun: [ヴァージン・ギャラクティック], Cluster: 9
# Noun: [カントリー・ガールズ], Cluster: 0
# Noun: [ウェブディレクトリ], Cluster: 2
# Noun: メリヤス, Cluster: 8
# Noun: [八角_(相撲)], Cluster: 0
# Noun: [ロードアイランド・スクール・オブ・デザイン], Cluster: 2
# Noun: [呂比須ワグナー], Cluster: 1
# Noun: 真先, Cluster: 4
# Noun: [デロレン祭文], Cluster: 8
# Processing batch 261...
# Noun: [河北華夏幸福足球倶楽部], Cluster: 3
# Noun: [政治資金団体], Cluster: 4
# Noun: [バンフィエルド], Cluster: 3
# Noun: [象牙芽細胞], Cluster: 6
# Noun: [アンパンマンの登場人物一覧], Cluster: 0
# Noun: すりガラス, Cluster: 2
# Noun: [東海インターチェンジ], Cluster: 1
# Noun: [バス海峡], Cluster: 7
# Noun: [エリミネーション・チェンバー・マッチ], Cluster: 3
# Noun: [レゾリューション_(帆船)], Cluster: 0
# Processing batch 263...
# Noun: 北斗旗, Cluster: 9
# Noun: [大橋トリオ], Cluster: 5
# Noun: [標葉郡], Cluster: 7
# Noun: 眼疾, Cluster: 2
# Noun: [持仏堂], Cluster: 0
# Noun: 郷党, Cluster: 0
# Noun: [徳川女系図], Cluster: 3
# Noun: [ビフレスト], Cluster: 7
# Noun: 湖州, Cluster: 0
# Noun: [嚶鳴社], Cluster: 6
# Processing batch 264...
# Noun: [学校法人東海大学], Cluster: 4
# Noun: [ホーマー], Cluster: 3
# Noun: 孝王, Cluster: 9
# Noun: [ニトロソ化合物], Cluster: 2
# Noun: [アルテ・ピナコテーク], Cluster: 8
# Noun: [口頭言語], Cluster: 2
# Noun: [バディ], Cluster: 5
# Noun: [コーナードラマ], Cluster: 5
# Noun: [エフゲニー・オネーギン_(オペラ)], Cluster: 0
# Noun: [インフィニティ・Q], Cluster: 4
# Processing batch 266...
# Noun: [ウクライナ正教会_(モスクワ総主教庁系)], Cluster: 5
# Noun: [甕城], Cluster: 1
# Noun: [阿波電気軌道], Cluster: 0
# Noun: [天神橋筋商店街], Cluster: 0
# Noun: [隆熙], Cluster: 4
# Noun: [ビスマルク体制], Cluster: 5
# Noun: [HAART療法], Cluster: 3
# Noun: [カット主戦型], Cluster: 2
# Noun: [ルドルフ4世], Cluster: 4
# Noun: [メディケア_(アメリカ合衆国)], Cluster: 1
# Processing batch 268...
# Noun: [二十七宿], Cluster: 2
# Noun: 者同盟, Cluster: 3
# Noun: [未婚], Cluster: 7
# Noun: [ゾンネベルク], Cluster: 3
# Noun: [イヤーエイク・レコード], Cluster: 6
# Noun: [イライジャ・ウッド], Cluster: 6
# Noun: 移民受け入れ, Cluster: 7
# Noun: [ドニプロ・ウクライナ], Cluster: 3
# Noun: [ハーロウ・ロンドン特別区], Cluster: 3
# Noun: [レイ_(イラン)], Cluster: 3
# Processing batch 269...
# Noun: [スカラー乗法], Cluster: 3
# Noun: [ボスマン判決], Cluster: 8
# Noun: [円理], Cluster: 3
# Noun: [フランケル_(競走馬)], Cluster: 8
# Noun: 反資本主義, Cluster: 1
# Noun: [北人], Cluster: 5
# Noun: 卵胞, Cluster: 3
# Noun: 舶来品, Cluster: 2
# Noun: 燃えさし, Cluster: 2
# Noun: [駅そば], Cluster: 4
# Processing batch 271...
# Noun: 共産党機関紙, Cluster: 0
# Noun: 中野学校, Cluster: 3
# Noun: [元徽], Cluster: 2
# Noun: [死罪_(律令法)], Cluster: 2
# Noun: [北九州貨物ターミナル駅], Cluster: 9
# Noun: [スタージョン級原子力潜水艦], Cluster: 9
# Noun: [出版条例], Cluster: 5
# Noun: [ヨシキリザメ], Cluster: 6
# Noun: [尖圭コンジローマ], Cluster: 1
# Noun: 風変り, Cluster: 8
# Processing batch 273...
# Noun: 劇詩, Cluster: 1
# Noun: [ヤットデタマン], Cluster: 7
# Noun: [武道館_(アルバム)], Cluster: 4
# Noun: [テルマエ・ロマエ], Cluster: 7
# Noun: [第一種免許], Cluster: 6
# Noun: [穂積親王], Cluster: 8
# Noun: [対称テンソル], Cluster: 2
# Noun: リー夫人, Cluster: 1
# Noun: [内湖区], Cluster: 9
# Noun: [神経心理学], Cluster: 2
# Processing batch 275...
# Noun: [九鬼産業], Cluster: 6
# Noun: [視床下核], Cluster: 3
# Noun: [栄光ゼミナール], Cluster: 6
# Noun: 対ドル, Cluster: 0
# Noun: [カール・ヴィルヘルム・シェーレ], Cluster: 3
# Noun: [役牌], Cluster: 3
# Noun: 業務停止処分, Cluster: 4
# Noun: [さいたま市立浦和南高等学校], Cluster: 1
# Noun: [2008年のインディカー・シリーズ], Cluster: 1
# Noun: [2015年のFIA_世界耐久選手権], Cluster: 1
# Processing batch 276...
# Noun: 資本蓄積, Cluster: 9
# Noun: 閣外大臣, Cluster: 1
# Noun: 傷痍, Cluster: 1
# Noun: [替紋], Cluster: 2
# Noun: [ゴッタルド鉄道トンネル], Cluster: 4
# Noun: G系, Cluster: 6
# Noun: [アニメ魂], Cluster: 8
# Noun: [ホイットニー美術館], Cluster: 7
# Noun: [桃園国際野球場], Cluster: 4
# Noun: [燃え尽き症候群], Cluster: 9
# Processing batch 278...
# Noun: [籠神社], Cluster: 7
# Noun: [ルイ・アントワーヌ_(アングレーム公)], Cluster: 1
# Noun: [PVC], Cluster: 2
# Noun: [茨城県立竜ヶ崎第一高等学校], Cluster: 4
# Noun: 土着宗教, Cluster: 7
# Noun: [アメリカ連合国陸軍長官], Cluster: 1
# Noun: [ドラゴンボールオンライン], Cluster: 0
# Noun: 鷲掴み, Cluster: 3
# Noun: [イボ族], Cluster: 6
# Noun: [中越鉄道], Cluster: 5
# Processing batch 280...
# Noun: [サンデー_(ホームセンター)], Cluster: 9
# Noun: [イーストポイント], Cluster: 6
# Noun: [オオバコ], Cluster: 5
# Noun: 骨牌, Cluster: 8
# Noun: [安山線], Cluster: 9
# Noun: [ニューモシスチス肺炎], Cluster: 5
# Noun: [交響曲第4番_(マーラー)], Cluster: 6
# Noun: [スペンス], Cluster: 4
# Noun: 井土ヶ谷, Cluster: 9
# Noun: [クロミスタ], Cluster: 5
# Processing batch 282...
# Noun: [虎牢関], Cluster: 4
# Noun: [カルロス・サウラ], Cluster: 6
# Noun: 縞柄, Cluster: 0
# Noun: [平成3年台風第19号], Cluster: 6
# Noun: カンフー映画, Cluster: 3
# Noun: [有功章], Cluster: 0
# Noun: [大雄宝殿], Cluster: 8
# Noun: [体性感覚], Cluster: 7
# Noun: [カンタブリア海], Cluster: 9
# Noun: [奥山廻り], Cluster: 8
# Processing batch 283...
# Noun: [巻上公一], Cluster: 4
# Noun: [マリオカート8], Cluster: 9
# Noun: [サブリナ], Cluster: 4
# Noun: [ハーミーズ_(空母・2代)], Cluster: 4
# Noun: [あきたこまち], Cluster: 1
# Noun: 東京国立博物館, Cluster: 8
# Noun: アカウンティング, Cluster: 7
# Noun: [エリウゲナ], Cluster: 5
# Noun: [蓄圧式ハイブリッド], Cluster: 7
# Noun: [サヌール], Cluster: 0
# Processing batch 285...
# Noun: [Donut], Cluster: 3
# Noun: 書紀, Cluster: 1
# Noun: [テーラモ], Cluster: 8
# Noun: [日本大学歯学部・大学院歯学研究科], Cluster: 5
# Noun: [人狐], Cluster: 2
# Noun: [ジャッジ], Cluster: 4
# Noun: [ユリノキ], Cluster: 6
# Noun: [旧大陸], Cluster: 6
# Noun: [ニップル_(機械)], Cluster: 6
# Noun: 貴音, Cluster: 7
# Processing batch 287...
# Noun: ねっとわーく, Cluster: 2
# Noun: [アイスホッケースウェーデン代表], Cluster: 5
# Noun: [日テレイベンツ], Cluster: 2
# Noun: [福音宣教省], Cluster: 1
# Noun: [バーナード・バトラー], Cluster: 9
# Noun: [健康ブーム], Cluster: 3
# Noun: [結合係数], Cluster: 7
# Noun: [全日本アイスホッケー選手権大会], Cluster: 5
# Noun: [台湾ドル], Cluster: 7
# Noun: [ノーフォーク伯爵], Cluster: 6
# Processing batch 289...
# Noun: で番, Cluster: 7
# Noun: [パタンジャリ], Cluster: 7
# Noun: [ウィリアム・マーシャル_(初代ペンブルック伯)], Cluster: 2
# Noun: [1963-1964シーズンのNBA], Cluster: 4
# Noun: 大規模, Cluster: 0
# Noun: 士風, Cluster: 7
# Noun: [VOS3], Cluster: 8
# Noun: 旧日本海軍, Cluster: 9
# Noun: [論理ゲート], Cluster: 8
# Noun: 金回り, Cluster: 3
# Processing batch 290...
# Noun: [エルゼンフェルト], Cluster: 7
# Noun: セクレタリー, Cluster: 4
# Noun: [BBCフィルハーモニック], Cluster: 0
# Noun: イギリスグランプリ, Cluster: 4
# Noun: [易州], Cluster: 2
# Noun: [下位運動ニューロン], Cluster: 8
# Noun: [料理物語], Cluster: 6
# Noun: [ジョージ・デューク], Cluster: 0
# Noun: [カオスガンダム], Cluster: 3
# Noun: [シンチレータ], Cluster: 8
# Processing batch 292...
# Noun: [Category:楽曲_に], Cluster: 5
# Noun: 真武, Cluster: 3
# Noun: [文春新書], Cluster: 0
# Noun: [エスパーニャ・ベルデ], Cluster: 1
# Noun: [ロシア連邦安全保障会議], Cluster: 1
# Noun: [梓], Cluster: 6
# Noun: [三日月藩], Cluster: 3
# Noun: [バッティカロア], Cluster: 1
# Noun: スターバックス, Cluster: 9
# Noun: [ジャンク船], Cluster: 1
# Processing batch 294...
# Noun: [コニツ], Cluster: 2
# Noun: [IndyCar], Cluster: 0
# Noun: 韻尾, Cluster: 6
# Noun: [Affero_General_Public_License], Cluster: 6
# Noun: [Tony], Cluster: 5
# Noun: 日本メディア, Cluster: 5
# Noun: [織田長政_(大名)], Cluster: 7
# Noun: [戦車第2師団_(日本軍)], Cluster: 9
# Noun: [伝法灌頂], Cluster: 7
# Noun: [長崎県知事一覧], Cluster: 3
# Processing batch 296...
# Noun: [飛行戦隊], Cluster: 4
# Noun: 炉辺, Cluster: 7
# Noun: [Category:アポロ計画], Cluster: 4
# Noun: 岳地帯, Cluster: 3
# Noun: [コパ・スダメリカーナ2016_決勝トーナメント], Cluster: 0
# Noun: [スーツ], Cluster: 7
# Noun: [スウィフト_(人工衛星)], Cluster: 0
# Noun: [アシナガグモ], Cluster: 3
# Noun: [グレプ・フセスラヴィチ], Cluster: 5
# Noun: fc2, Cluster: 2
# Processing batch 297...
# Noun: [2001年ワールドグランドチャンピオンズカップ], Cluster: 9
# Noun: [甘み], Cluster: 0
# Noun: [ゼンダマン], Cluster: 7
# Noun: [硫化水銀], Cluster: 0
# Noun: [蛍光抗体法], Cluster: 3
# Noun: [イボア], Cluster: 9
# Noun: [レッドウッドシティ], Cluster: 9
# Noun: [LDH], Cluster: 9
# Noun: [木_(栃木市)], Cluster: 1
# Noun: [オーフス大学], Cluster: 8
# Processing batch 299...
# Noun: [仙台鎮台], Cluster: 0
# Noun: [保険外併用療養費], Cluster: 1
# Noun: [アタッチメント], Cluster: 3
# Noun: [ケヴァン・ラニスター], Cluster: 8
# Noun: [ポケットベル], Cluster: 9
# Noun: 大枚, Cluster: 5
# Noun: [多雨林], Cluster: 5
# Noun: [2006_FIFAワールドカップ・オセアニア予選], Cluster: 7
# Noun: [左再帰], Cluster: 3
# Noun: [ブレイド_(映画)], Cluster: 6
# Processing batch 301...
# Noun: [易者], Cluster: 9
# Noun: 屏風浦, Cluster: 0
# Noun: 光の, Cluster: 6
# Noun: [アルカノイド], Cluster: 3
# Noun: [京都市営バス横大路営業所], Cluster: 0
# Noun: [太平洋フェリー], Cluster: 0
# Noun: [アイリス_(列車)], Cluster: 3
# Noun: [ヴァーツラフ1世_(ボヘミア公)], Cluster: 1
# Noun: [八代将軍吉宗], Cluster: 3
# Noun: [リラ], Cluster: 1
# Processing batch 303...
# Noun: [霊魂ch], Cluster: 6
# Noun: [シピフル・シコー], Cluster: 8
# Noun: [2003年のJリーグカップ], Cluster: 4
# Noun: [仙台空港駅], Cluster: 7
# Noun: [スカートめくり], Cluster: 3
# Noun: [日高スタリオンステーション], Cluster: 4
# Noun: こうけつ, Cluster: 9
# Noun: [シェル石油], Cluster: 1
# Noun: [フォッシュ_(空母)], Cluster: 5
# Noun: [東京テレポートセンター], Cluster: 7
# Processing batch 304...
# Noun: [マーナ・ロイ], Cluster: 1
# Noun: [仏教伝道文化賞], Cluster: 1
# Noun: [マグプル], Cluster: 6
# Noun: [防塵], Cluster: 9
# Noun: [アレクサンデル6世], Cluster: 8
# Noun: [ナイトレイジ], Cluster: 1
# Noun: [SBS人気歌謡], Cluster: 2
# Noun: [内裏式], Cluster: 2
# Noun: [パキケファロサウルス], Cluster: 4
# Noun: [中野友加里], Cluster: 1
# Processing batch 306...
# Noun: [アルブレヒト・フォン・ヴュルテンベルク], Cluster: 7
# Noun: [鳥栖筑紫野道路], Cluster: 2
# Noun: [EBITDA], Cluster: 6
# Noun: [オレンジ計画], Cluster: 0
# Noun: [イタリア国鉄ETR460電車], Cluster: 6
# Noun: [キャッスルフォアコート], Cluster: 2
# Noun: 志らく, Cluster: 3
# Noun: [南部州_(スリランカ)], Cluster: 2
# Noun: 防衛計画の大綱, Cluster: 6
# Noun: [アルバセテ県], Cluster: 2
# Processing batch 308...
# Noun: [吉田道場], Cluster: 5
# Noun: [TBSビジョン], Cluster: 2
# Noun: 公共福祉, Cluster: 9
# Noun: [ヌーヴォレコルト], Cluster: 5
# Noun: [カレント], Cluster: 0
# Noun: 重陽, Cluster: 6
# Noun: [良心の囚人], Cluster: 9
# Noun: [クルーズグループ], Cluster: 5
# Noun: [旅の仲間], Cluster: 3
# Noun: [テウェルチェ族], Cluster: 8
# Processing batch 310...
# ...
# Noun: 土師ノ里, Cluster: 4
# Noun: グリーンルート, Cluster: 3
# Noun: とうみつ, Cluster: 4
# Noun: [ヘブリディーズ海], Cluster: 6
# Noun: [五種の神器], Cluster: 4
# Noun: ょうかいとくむてい, Cluster: 7
# Noun: [シロイボカサタケ], Cluster: 4
# Noun: [赤い刀], Cluster: 8
# Noun: [つくし], Cluster: 1
# Processing batch 996...
# Noun: [アンジュ], Cluster: 0
# Noun: [MEE], Cluster: 0
# Noun: [ヘンリー・スタフォード_(初代ウィルトシャー伯)], Cluster: 4
# Noun: [予備戦線], Cluster: 0
# Noun: [マーラ山地], Cluster: 7
# Noun: [#N2000系], Cluster: 0
# Noun: [Carl_Friedrich_Gauss], Cluster: 4
# Noun: [ウルトラ・ダラー], Cluster: 3
# Noun: [銀河丸], Cluster: 7
# Noun: [:en:The_Detective_(novel)], Cluster: 9
# Processing batch 998...
# Noun: [アルフレッド・グウィン・ヴァンダービルト2世], Cluster: 4
# Noun: [コスタ・コンコルディアの座礁事故], Cluster: 2
# Noun: 役小角, Cluster: 0
# Noun: グリーンカレー, Cluster: 3
# Noun: [お笑いポポロ], Cluster: 0
# Noun: [テレコミュニケーション], Cluster: 2
# Noun: [セルジュ・ドゥブロフスキー], Cluster: 2
# Noun: [ビビンククス], Cluster: 9
# Noun: [mitスーパーニュース], Cluster: 4
# Noun: 年金者, Cluster: 7
# Processing batch 1000...
# Noun: 台風5号, Cluster: 1
# Noun: [第34回全国高等学校バスケットボール選抜優勝大会], Cluster: 9
# Noun: [CBCラジオ虎の穴], Cluster: 5
# Noun: [トバイアス・フルノー], Cluster: 6
# Noun: 骨董通り, Cluster: 8
# Noun: [ミヤマエンレイソウ], Cluster: 4
# Noun: [アンドレ・マルシャル], Cluster: 9
# Noun: [ブライアン・ジョゼフソン], Cluster: 4
# Noun: [ラウール＝オージェ・フイエ], Cluster: 6
# Noun: [エーリッヒ・フォン・デニケン], Cluster: 4
# Processing batch 1001...
# Noun: [Q-Tip], Cluster: 0
# Noun: [レオポルト2世_(オーストリア辺境伯)], Cluster: 1
# Noun: [ママカースト], Cluster: 6
# Noun: [換語], Cluster: 2
# Noun: [KEIRINグランプリ2000], Cluster: 4
# Noun: [エヴァ・ハーツィゴヴァ], Cluster: 3
# Noun: [Β-ラクタム系抗生物質], Cluster: 3
# Noun: 当り障り, Cluster: 0
# Noun: [トリカスタン原子力地区], Cluster: 0
# Noun: [ムラウチドットコム], Cluster: 3
# Processing batch 1003...
# Noun: 三つの指輪, Cluster: 8
# Noun: [ロ式輸送機], Cluster: 6
# Noun: [昭和41年台風第24・26号], Cluster: 2
# Noun: [:en:History_of_the_formation_of_the_United_Kingdom], Cluster: 2
# Noun: 資産価格付けの基本定理, Cluster: 2
# Noun: [紅殻のパンドラ], Cluster: 0
# Noun: [イレーン・チャオ], Cluster: 2
# Noun: [mod_python], Cluster: 9
# Noun: [中宮ダム], Cluster: 3
# Noun: [あゝ!一軒家プロレス], Cluster: 5
# Processing batch 1005...
# Noun: [#UCポイント], Cluster: 7
# Noun: [ヴワディスワフ], Cluster: 2
# Noun: 鶉尾, Cluster: 9
# Noun: [真昼ノ星空], Cluster: 5
# Noun: 五月晴れ, Cluster: 6
# Noun: [自主憲法], Cluster: 1
# Noun: [三瀬諸淵], Cluster: 2
# Noun: [バート・バーンズ], Cluster: 6
# Noun: 岩崎城, Cluster: 2
# Noun: 売上高経常利益率, Cluster: 3
# Processing batch 1007...
# Noun: [アッパークラマス湖], Cluster: 2
# Noun: [にっぽん愉快家族], Cluster: 7
# Noun: [collectivist_anarchism], Cluster: 3
# Noun: [トルネード・アレイ], Cluster: 7
# Noun: [天橋立鋼索鉄道], Cluster: 3
# Noun: [グスタフ・フィリップ・クロイツ], Cluster: 7
# Noun: [ケビン・グリーン], Cluster: 9
# Noun: [みどりといのちの市民・農民連合], Cluster: 9
# Noun: [藤堂長教], Cluster: 3
# Noun: [ツルギキョウ], Cluster: 3
# Processing batch 1009...
# Noun: [フィコプラスト], Cluster: 3
# Noun: [ボガチョンコフ事件], Cluster: 3
# Noun: [ブラウザホン641S], Cluster: 5
# Noun: [レニナバード], Cluster: 2
# Noun: [気賀勘重], Cluster: 3
# Noun: [船員図書館], Cluster: 9
# Noun: [なつみん], Cluster: 8
# Noun: [ブレイン・アンダーソン], Cluster: 2
# Noun: [大元メディア], Cluster: 0
# Noun: [ローズ環礁], Cluster: 0
# Processing batch 1011...
# Noun: [新潟市道弁天線], Cluster: 6
# Noun: [豊見城・名嘉地インターチェンジ], Cluster: 2
# Noun: [ヘンダーソンヴィル], Cluster: 0
# Noun: [第44回明治神宮野球大会], Cluster: 6
# Noun: 一般訓練, Cluster: 3
# Noun: 御中道, Cluster: 0
# Noun: [セルボーン伯爵], Cluster: 2
# Noun: [ビトゥリゲス族], Cluster: 8
# Noun: [ニコラ・カビボ], Cluster: 3
# Noun: [KEY_PARTY], Cluster: 6
# Processing batch 1012...
# Noun: [ヴァイパー_(バンド)], Cluster: 1
# Noun: [ペレムィシュリ_(カルーガ州)], Cluster: 6
# Noun: [ヘブル語], Cluster: 7
# Noun: [.38-55ウィンチェスター弾], Cluster: 8
# Noun: [ゆとりですがなにか], Cluster: 4
# Noun: [Survivor], Cluster: 1
# Noun: [ENEOSプレゼンツ_あさナビ], Cluster: 4
# Noun: 公史, Cluster: 1
# Noun: [FV103_スパルタン], Cluster: 6
# Noun: [#ハイ・キューブ・コンテナ], Cluster: 5
# Processing batch 1014...
# Noun: [学力テスト], Cluster: 4
# Noun: [グレッグ・バーグドルフ], Cluster: 4
# Noun: [平良良松], Cluster: 5
# Noun: [桑原宿], Cluster: 2
# Noun: [アイワン], Cluster: 7
# Noun: [インゲルハイム], Cluster: 9
# Noun: [久我山大学], Cluster: 4
# Noun: [犠牲者非難], Cluster: 2
# Noun: [沖縄ワールドリングボクシングジム], Cluster: 4
# Noun: [長岡京インターチェンジ], Cluster: 7
# Processing final batch...
# Noun: [沖縄国税事務所], Cluster: 7
# Noun: [h.o.p.s.], Cluster: 3
# Noun: [豆電球], Cluster: 7
# Noun: [ヘリーハンセン], Cluster: 2
# Noun: [大門川_(北杜市)], Cluster: 4
# Noun: [ジオ・ポンティ], Cluster: 4
# Noun: [国立博物館_(ニューデリー)], Cluster: 4
# Noun: [プラネット・ウェイヴズ], Cluster: 3
# Noun: [カロリーネ・シェリング], Cluster: 1
# Noun: [アイスキューブ・ニュートリノ観測所], Cluster: 5
# ----- クラスタごとのサンプリング結果 -----
#
# Cluster 2:
#   スタンダードミサイル
#   [肝付兼元]
#   MR2
#   山際
#   セイリング
#   [国旗団_(ドイツ社会民主党)]
#   [チロルチョコ]
#   [キンボール・インターナショナル]
#   常次
#   [貸金業の規制等に関する法律]
#   [ブランドン・モス]
#   [Category:セゾンカード]
#   [スカイブルー]
#   [ジェラール・コルビオ]
#   [堂宇]
#   [Web担当者Forum]
#   郎等
#   大雄寺
#   [ガイウス_(法学者)]
#   夢工房
#   [W3事件]
#   [あ段]
#   [仙台市立上杉山中学校]
#   蘆溝橋事件
#   [聖ネデリャ教会]
#   血栓性静脈炎
#   [日体大長距離記録会]
#   [ウィンターゲームズニュージーランドフィギュアスケート競技]
#   [日本歯科放射線学会]
#   [神仙]
#   [2007年NHK杯国際フィギュアスケート競技大会]
#   [電磁界]
#   ももいろクローバーZ
#   早稲田大学理工学部
#   [産学官連携]
#   [日本プロレス中継]
#   [ヤクシャ・マッラ]
#   [カイル・ヘンドリックス]
#   [ピナレロ]
#   [ディック・ヴァーミール]
#   [インターハイ]
#   [ホームセキュリティ]
#   とろろ汁
#   [ベルリン国立図書館]
#   [ヨハン・ラッテンフーバー]
#   [藤原子高]
#   [エクソダスギルティー]
#   [#レギュラーシーズン]
#   [近点月]
#   [名古屋市文化小劇場]
#   人の一生
#   テンションパーマ
#   ダチョウ
#   セットプレー
#   [国際ユダヤ人スポーツ殿堂]
#   [名誉修士]
#   [Category:UEFA_U-21欧州選手権2017_(予選)]
#   [南伊佐郡]
#   [ドロマエオサウルス科]
#   [浅瀬石川ダム]
#   [ジェーン・バーキン]
#   長か
#   [食習慣]
#   ろうさい
#   [Category:宮尾登美子]
#   [狼林郡]
#   [ピローク]
#   [ヴォトキンスク]
#   [鷲の戦士]
#   [Ju_388]
#   非戦闘地域
#   [トダシバ]
#   鋸
#   [メルカバ_(戦車)]
#   [蠍座]
#   [VRC_VI]
#   [セント・メリーズ・インターナショナル・スクール]
#   [縮みゆく人間]
#   高野山真言宗
#   [ハッピーホテル]
#   獄門
#   [Berkeley_Software_Distribution]
#   [ウェストミフリン]
#   [U(1)]
#   [ロンセストン]
#   [ウッドマイルズ]
#   [2016年のNBAドラフト]
#   [耐え難き諸法]
#   [コンチェルティーノ]
#   [立命館UBCハウス]
#   売上高営業利益率
#   [宗]
#   [コーヒーカップ_(遊具)]
#   [アレクサンドル・モギレフスキー]
#   伊方原発
#   万沙子
#   [鳥媒花]
#   [萩]
#   [イスカンダル・シャー_(マラッカ王)]
#   年譜
#
# Cluster 3:
#   [アルノルド・アレマン]
#   [ヌケヌケ]
#   [テレビグランドスペシャル]
#   トーランド
#   [ラストマン・スタンディング・マッチ]
#   パレットプラザ
#   ふつ
#   [委員長決裁]
#   [大分七夕まつり]
#   写字
#   [補陀洛山]
#   [名取市立愛島小学校]
#   [エルンスト・フォン・ヘッセン＝フィリップスタール]
#   [ザイヌル・アービディーン_(カシュミール・スルターン朝)]
#   [電子契約]
#   [JR時刻表]
#   [本屋]
#   すすき
#   [港区立赤坂中学校]
#   [カッチ王国]
#   大提灯
#   [デジタル証明書]
#   東京乾電池
#   元朝日新聞記者
#   [泉藩]
#   [#順番交替]
#   [シン・サテライト]
#   [仁川交通公社]
#   [北海道大谷室蘭高等学校]
#   [パッチギ!]
#   [悪臭防止法]
#   れんごく
#   [赤唐辛子]
#   [呼揭単于]
#   遅筆
#   [蚕種]
#   [ニューヨーク・エア・ブレーキ]
#   [宮本武之輔]
#   [核戦略]
#   [グランドスラム・アブダビ2015]
#   [東京圏における今後の都市鉄道のあり方について]
#   [人民艦隊]
#   [装いの街]
#   [屋鋪要]
#   [両院制]
#   [聖シルベストロ教皇騎士団勲章]
#   [アンドレア・キトゥ]
#   [岐阜市立加納中学校]
#   [ローランド・ブーデュアニ]
#   墨堤通り
#   [新潟県立新潟南高等学校]
#   [アフリカウスイロイルカ]
#   [恩給]
#   [流域圏]
#   [多胞体の面]
#   [ブニヤウイルス科]
#   先出し
#   [松戸神社]
#   [デ・ハビランド・カナダ_DHC-3]
#   [アウンサン]
#   [ゲルハルト・エルトル]
#   [s]
#   [安熙正]
#   中間
#   [木寺宮康仁親王]
#   財政法
#   スペクタクル
#   [#球場の運営]
#   無償交換
#   [ポッ拳_POKKÉN_TOURNAMENT]
#   [スーパーリーグ]
#   [資料館]
#   [エディプスの恋人]
#   [シニアカー]
#   [電車ごっこ]
#   [偏光顕微鏡]
#   国政選挙
#   [小倉王]
#   [第2次キャメロン内閣]
#   特殊関数
#   [松山勘十郎]
#   [テュペロ・ハニー]
#   翳り
#   [西武5000系電車]
#   [群生地]
#   にょたい
#   [冶金学者]
#   おばあちゃん
#   [ランガナタン]
#   [槌]
#   [彦根高等商業学校]
#   [並木_(つくば市)]
#   書籍化
#   [メーリオネース]
#   ジョンソン宇宙センター
#   てんきゅう
#   [周鴻慶]
#   ふ人
#   [ヴィジェーヴァノ]
#   そば屋
#
# Cluster 5:
#   [能満寺_(吉田町)]
#   チェーン
#   [松阪市図書館]
#   [加藤嘉矩]
#   [ウェイン・レイニー]
#   [エルゼ・ラスカー＝シューラー]
#   [TC2000]
#   [コタキナバル国際空港]
#   [悪地]
#   [第100師団_(日本軍)]
#   得よ
#   [ケータイ刑事_銭形シリーズの登場人物]
#   [テープアウト]
#   顔写真
#   根切り
#   [スペシャル・ライセンス・プレーヤー]
#   代替燃料
#   [とんねるずのみなさんのおかげでした]
#   [NFL_on_NBC]
#   [森博幸_(野球)]
#   [親衛隊及び警察指導者]
#   [管叔鮮]
#   [住所証明情報]
#   レンタルサーバー
#   [アルフレッド・P・スローン]
#   [他人の関係]
#   [下駄記号]
#   [三島神社のキンモクセイ]
#   [コンチネンタル・ミクロネシア]
#   [渥美坂井法律事務所・外国法共同事業]
#   [ロストヴェツ_(ルーシ)]
#   [学士院会員]
#   [ルーツ・ミュージック]
#   かいにゅう
#   企業情報
#   [RYU]
#   [証拠調べ]
#   [甲子園競輪場]
#   逆撫で
#   [大和茶]
#   [セブンシーズ・エンターテインメント]
#   [千住ミルディス]
#   [朱鷺田祐介]
#   [ヴィルヘルム1世_(マイセン辺境伯)]
#   [Xperia_acro]
#   [香本]
#   [ブロウトコヴァ・ヴェリカンカ]
#   さんご
#   [東京都立永山高等学校]
#   シンスキー
#   [サンタ・クローチェ聖堂]
#   災害派遣医療チーム
#   [レント_(ミュージカル)]
#   音声
#   [オールドオーチャードビーチ]
#   国領
#   [呪い]
#   ゆうすい
#   [ヤシ]
#   [バガーリ・ドッグ]
#   地域新聞
#   [日曹炭鉱天塩砿業所専用鉄道]
#   [ドゴン族]
#   建築設計事務所
#   楽屋ネタ
#   [監獄学園]
#   超鈴音
#   お手上げ
#   [シャー・ジャハーン]
#   [ヤンチャン学園_音楽部]
#   兄弟姉妹
#   [フェアウェザー氷河]
#   [海曹]
#   [朴世永]
#   [地獄少女_(漫画)]
#   [スーダンのロストボーイズ]
#   [SM嬢]
#   [クシシュトフ・ザヌッシ]
#   [UR賃貸住宅]
#   同志会
#   さらば青春の光
#   [普天間基地]
#   [ろ座銀河団]
#   [有限合資会社]
#   [粘板岩]
#   [Category:中華民国の人物_ふ]
#   [サウンドスキャン]
#   [リバス県]
#   しょうりょうえ
#   [iXIT]
#   [COTTON_USAアワード]
#   [ヨシア]
#   国名
#   [イーストマン音楽院]
#   [クレヨンしんちゃん_ガチンコ!逆襲のロボとーちゃん]
#   [別件逮捕]
#   要訣
#   [アイアンハンマー]
#   [蘭欽]
#   [2011年パシフィックゲームズにおけるサッカー競技]
#
# Cluster 8:
#   すりばち
#   [製菓衛生師養成施設]
#   発行済株式数
#   [平野庄]
#   [スパイズ・ライク・アス]
#   東海ラジオ
#   [マリー・レクザンスカ]
#   [競艇]
#   プルーフ
#   [横浜競馬場]
#   尼ヶ辻
#   差込み
#   [インデペンデント映画]
#   真宗高田派
#   [二項係数]
#   石炭化学
#   俳諧師
#   日本国王
#   [CV]
#   ぱつ
#   [砂糖依存症]
#   [ネスチン]
#   [ターボライナー]
#   [フランク・キャプラ]
#   [アイルランド海]
#   [ベルリンフィル]
#   博物館
#   [グラヤノトキシン]
#   [中央_(鎌ケ谷市)]
#   リゾート地
#   [ブレイド2]
#   [ミカエル・ラウドルップ]
#   [ヒ88J船団]
#   eコマース
#   [澄江寺]
#   どくさいスイッチ
#   [合掌捻り]
#   [カマラン島]
#   [浦えりか]
#   [南条氏の当主・一族一覧]
#   [A1_チーム・ドイツ]
#   [スーダ辞典]
#   [RealLive]
#   [Program_Evaluation_and_Review_Technique]
#   水玉
#   [SO-04D]
#   際大会
#   [ロシュ_(アンドル＝エ＝ロワール県)]
#   [直角カルダン駆動方式]
#   [秀英体]
#   [ズワン]
#   [ふられ気分でRock'n'_Roll]
#   [八点鐘]
#   [稲麹]
#   [楊済]
#   [コクレーン地区]
#   [イットリンゲン]
#   礒貝
#   エビ
#   画材
#   [シグー]
#   広域電鉄
#   [ジロー・オペラ賞]
#   [イタリアンレッド]
#   [黄金勇者ゴルドラン]
#   一向聴
#   [特許庁長官]
#   の裁判所
#   テニス漫画
#   [禁書目録]
#   [CXAM]
#   [ソイレント・グリーン]
#   [アブラナ科]
#   治験
#   [エイドリアン・ブローナー]
#   [ワシントン・カーネギー協会]
#   [背子]
#   [臨時召物]
#   [伊豆山権現]
#   [#自動閉塞式]
#   [中央競馬実況中継_(日経ラジオ社)]
#   [東建多度カントリークラブ・名古屋]
#   [レチクル]
#   [童夢_(アニメ制作会社)]
#   ラスト・ワルツ
#   [フアード2世_(エジプト王)]
#   [ネスター]
#   ライヴ・イン・ジャパン
#   甲冑
#   [ひまわり_(遊助の曲)]
#   [カイザーロール]
#   [影のピラミッド]
#   [伊藤伝右衛門]
#   [アルヴィス・カー・アンド・エンジニアリング・カンパニー]
#   [ハイアリア]
#   [住居番号]
#   [共産主義者同盟赤軍派]
#   [国民体育大会ハンドボール競技]
#   ジョプリン得能
#   [鹿児島県立種子島高等学校]
#
# Cluster 0:
#   [ムワタリ2世]
#   [彼と人生]
#   文明批評
#   ディナークルーズ
#   [ヴィクトル・アマデウス]
#   [F-15SE]
#   [イオンモール名取]
#   [コンウォール・リー]
#   会所
#   [松平直矩]
#   [ジョゼフ・ガリエニ]
#   [ジャパンラグビートップリーグ2009-2010]
#   [パーシヴァル]
#   中肉
#   根絶やし
#   [満洲事変]
#   の真実
#   [DREAM.2]
#   [ラクトアルデヒド]
#   [ブルーコンコルド]
#   金陵
#   架線
#   [バロック美術]
#   エスオーエス
#   共産主義者同盟
#   [一党優位政党制]
#   [道_(EXILEの曲)]
#   [セリエA_(サッカー)]
#   [The_BBB]
#   [納見佳容]
#   [安全保障政策]
#   [マリク・アンバル]
#   [アルダナーリーシュヴァラ]
#   サロ212
#   [トシリズマブ]
#   [ノゾキ]
#   [ピューマ]
#   [煮干]
#   [法政大学中学高等学校]
#   [準備通貨]
#   霊
#   [マルク・ゴンサレス]
#   [化石人骨]
#   [心はロンリー気持ちは「…」]
#   キロバトル
#   [鳥羽絵]
#   [ジョージ・ハーバート・ウォーカー]
#   [コンサートマスター]
#   田園都市
#   実益
#   [キャデラック・シマロン]
#   [カルン・チャンドック]
#   [RHYMESTER]
#   [梓書院]
#   [アドルフ・ハーセス]
#   [八戸市体育館]
#   [ホレス・グリーリー]
#   [国際航業ホールディングス]
#   [テディ_(競走馬)]
#   聖廟
#   [マンション一括受電]
#   [アンドレイ・グレチコ]
#   [邯鄲_(戯曲)]
#   [グリーンダムたん]
#   [家計調査]
#   [ヴァースキ]
#   基本法
#   [董賢]
#   [ノーフォークマツ]
#   [タンボフ県]
#   [山田乙三]
#   適正価格
#   輪湖
#   [ガラン]
#   [おでん]
#   [ゲーリー_(インディアナ州)]
#   [岩国市営錦バス]
#   [九州産交バス]
#   [#主題歌]
#   [知行合一]
#   [ゲンゴロウブナ]
#   [対称空間]
#   新作落語
#   [デフバレーボール]
#   [ツユクサ]
#   [カーントン]
#   [佐鳴予備校]
#   [折田汽船]
#   [老人保健施設]
#   [修飾キー]
#   中国大使館
#   [エッセネ派]
#   [フセヴォロド・スヴャトスラヴィチ_(キエフ大公)]
#   [カイラン]
#   企業組合
#   [生物無機化学]
#   [ご存知時代劇]
#   [シンクロ接点]
#   [シグマ粒子]
#   [異本]
#
# Cluster 7:
#   [OpenAFS]
#   人魚姫
#   [北村西望]
#   [駅舎]
#   [聖書翻訳]
#   二水記
#   [許志永]
#   [リベル・ウズアリス]
#   [日本のフリーメイソンリー]
#   [政治学科]
#   コタツ
#   [DD北斗の拳]
#   [タンク車]
#   [自由連合_(国家間関係)]
#   [ピーター・ベアズリー]
#   教養センター
#   浪曲師
#   [静岡県道21号三島裾野線]
#   [五山送り火]
#   音楽理論
#   [コレコビジョン]
#   [チンアナゴ]
#   [頂法寺]
#   [e_(mathematical_constant)]
#   [夏子の酒]
#   [ライブアルバム]
#   [申公豹]
#   [ホワイト・ビーチ地区]
#   言論弾圧
#   [社会主義同盟]
#   基部
#   スターバック
#   [#ピカピカ星人]
#   [平和基金会]
#   [UT-2]
#   [生活_(アルバム)]
#   [マルサスモデル]
#   [龍猛]
#   元宿
#   の帝王
#   牛膝
#   [レイヤ4スイッチ]
#   [ブレスト海峡]
#   [記述疫学]
#   [聖母教会_(ドレスデン)]
#   [セント・ジョンズ・カレッジ_(アメリカ合衆国)]
#   [ハーパーズ・フェリー級ドック型揚陸艦]
#   [比田井天来]
#   [AFCエシルストゥーナ]
#   [軍用車両]
#   A5
#   物心
#   [若い音楽家のためのチャイコフスキー国際コンクール]
#   [近鉄バファローズアワー]
#   [方天定]
#   [サンタアナ]
#   [青梅スタジアム]
#   [カトリック医師会]
#   [医長]
#   [交通遺児育英会]
#   [ハングオーバー!_消えた花ムコと史上最悪の二日酔い]
#   [エルネスト・マンデル]
#   [福岡航空交通管制部]
#   [住友セメント]
#   [蒲郡クラシックホテル]
#   [留別村]
#   [小児歯科学]
#   [Eチケット]
#   [地下ダム]
#   [セルゲイ・ラブロフ]
#   [レイランド・ナショナル]
#   [ウルトラマリン]
#   [ジェファーソン郡_(コロラド州)]
#   [中庸_(ギリシア哲学)]
#   源興
#   [IRNSS]
#   [シム・ウナ]
#   [#ランスタッグ]
#   [シンギュラー・ワイヤレス]
#   潮吹
#   [日本現報善悪霊異記]
#   [書物問屋]
#   [ブラックトップ・レコード]
#   天籟
#   [GOA]
#   [モンスターワールドシリーズ]
#   [七つの顔]
#   [交代代数]
#   [先天_(唐)]
#   [メシエカタログ]
#   リアルスコープ
#   [スワヒリ文明]
#   [BMW・700]
#   マルコム
#   シラカバ
#   闇屋
#   ナンバーワン
#   [塩原ダム]
#   [クリムゾン]
#   [トランター]
#
# Cluster 9:
#   [ドリフティング・カウボーイズ]
#   [痛悔機密]
#   [豊川鉄道]
#   阪堺電気軌道
#   [八幡大学]
#   字面
#   [カルロス・サリナス・デ・ゴルタリ]
#   [小学館文学賞]
#   出版取次
#   [刑法学者]
#   しーちゃん
#   [新アメリカ安全保障センター]
#   富士日記
#   [レイクハースト]
#   [花へんろ]
#   [芳香環]
#   [交通信号]
#   [JOCX-TV2]
#   [奈良学園小学校]
#   監視レーダー
#   島嶼群
#   花と果実
#   [EI法]
#   [ダニッチ]
#   [マリオ・プラーツ]
#   おすし
#   さいでん
#   [ギター奏者]
#   [ボリス・ティシチェンコ]
#   [憲章]
#   公共哲学
#   [姫路市立水族館]
#   [たかはしごう]
#   [ペイプシ湖]
#   [社会学者]
#   [猪鹿牧]
#   [カステルサラザン]
#   [韓国外国語大学校]
#   [うきしま]
#   [ダイムラー・ベンツ_DB_604]
#   [#南極条約の締結]
#   [パナソニック・パンサーズ]
#   [防災センター]
#   [シルヴェスター・リーヴァイ]
#   [横浜マリンタワー]
#   [M114_155mm榴弾砲]
#   [マレーシア証券取引所]
#   おみこし
#   [田島征彦]
#   [自主映画]
#   [大直交性定理]
#   [日本古生物学会]
#   [イギリス海軍の等級制度]
#   旧来
#   [ハプログループR_(Y染色体)]
#   [WORLD_WIDE_DEMPA]
#   ひね
#   快感原則
#   [Encore_V_〜20th_Anniversary_Concert_Tour,_'02_DO_MY_BEST〜]
#   [映画祭]
#   [触手動物]
#   [銭松]
#   [夏鐸鋪鎮]
#   [エクス・マキナ]
#   [おつやの方]
#   [扇町公園]
#   [オーギュスタン・ジャン・フレネル]
#   [マルシュ]
#   ニコチン酸
#   [プレスコット天文台]
#   自力更生
#   [:en:Mexico_City_Metro_Line_9]
#   [糖質コルチコイド]
#   [資本家]
#   変量
#   [千葉胤泰]
#   [日本ラグビーフットボール選手権大会]
#   [チェルムスフォード]
#   中村乙
#   [ゲデレー]
#   [クモ膜]
#   [レオウイルス科]
#   [欽州市]
#   [明日があるさ_THE_MOVIE]
#   [製造番号]
#   [国有鉄道_(フランス)]
#   呑兵衛
#   宗生
#   [セオドア・ルーズベルト_(空母)]
#   [2014_FIFAワールドカップ・決勝]
#   [ワンジェサン軽音楽団]
#   [ハンドスプリング・パペット・カンパニー]
#   [古川タク]
#   最後の恋
#   [ルテニア語]
#   [新井田公園]
#   [キバウミニナ]
#   [鷹尾城]
#   [イ式小銃]
#   [スタイロベート]
#
# Cluster 6:
#   [惑星X]
#   とんかち
#   [フランス西部自動車クラブ]
#   [New_Girl_/_ダサかわ女子と三銃士]
#   南方作戦
#   [吉村大志郎]
#   ぐうじ
#   [ダミア]
#   [K-5_(ミサイル)]
#   [イリシッド]
#   [ジャン＝マリー・ルクレール]
#   [杜周]
#   [ヨシガイ]
#   [異歯亜綱]
#   [777town.net]
#   気根
#   コンパクトシティ
#   [セレス県]
#   [エクスドライバー]
#   [麻布]
#   [ホンダワラ]
#   [ウォーカー・ギャリア]
#   [ベストフォーマリスト]
#   [シクロアルケン]
#   封切
#   モール店
#   [小南峠]
#   [レイ・ナイト]
#   [松来未祐]
#   [バルド]
#   [サマセット_(ペンシルベニア州)]
#   [超忍者隊イナズマ!]
#   [ベックレスピナクス]
#   目からウロコ
#   [2014年の音楽]
#   [ウェスティンホテル仙台]
#   [箇条書き]
#   [ハマランチョ]
#   着生植物
#   [皇霊祭]
#   [メルトラ]
#   [中間的就労]
#   ボギー台車
#   櫛枝実乃梨
#   服部学園
#   [イーストグリニッジ]
#   [ファニー・アルダン]
#   [コート＝ドール県]
#   [榊英雄]
#   [ビデ]
#   [アンドレア・テメシュバリ]
#   [高砂市立鹿島中学校]
#   ぜんかく
#   [セノオ楽譜]
#   [サンデー西京]
#   特救隊
#   [スコティッシュ・プレミアシップ_2014-15]
#   [うたかたの恋_(バレエ)]
#   興定
#   [実況パワフルプロ野球ポータブル4]
#   [アライド・アーティスト・ピクチャーズ・コーポレーション]
#   積極分子
#   [リグリア海]
#   若い力
#   つぶく
#   完全情報
#   [ナニワトモアレ]
#   [佐藤藤佐_(司法官)]
#   一番星
#   ビッグ7
#   [フロッグ_(模型メーカー)]
#   [のれん分け]
#   [宝塚市立長尾小学校]
#   [OpenCL]
#   [:de:Rupert_Butler]
#   [ハジロクロハラアジサシ]
#   [ウタウイヌ]
#   [寿スピリッツ]
#   [僕たちは世界を変えることができない。]
#   [朝鮮排華事件]
#   [与圧装置]
#   [ジョージ・ワシントン級原子力潜水艦]
#   [ランレベル]
#   [踵骨]
#   [バディサッカークラブ]
#   [サムスン・ライオンズ]
#   [BLENDA]
#   [徐世昌]
#   [フリッツ・ゼルニケ]
#   [TUYニュース]
#   [ラーナー]
#   [トランスフォーマー_アニメイテッド]
#   [フミノトキメキ]
#   [ジョニー・マティス]
#   [第15回気候変動枠組条約締約国会議]
#   [交通文化賞]
#   [ぼくの魔法使い]
#   [フライホイール・バッテリー]
#   [野生動物]
#   [劇場版_仮面ライダー電王_俺、誕生!]
#
# Cluster 1:
#   土湯
#   [スペリー]
#   [The_City_of_Light_/_Tokyo_Town_Pages]
#   のバス
#   下口
#   [WEBラジオ]
#   サンドペーパー
#   [:w:Drosera]
#   証券コード
#   崇福
#   明友
#   [ハリー・ハモンド・ヘス]
#   [トバイアス・マッセイ]
#   [コ・メディカル]
#   いらっしゃい
#   [スティーブン・ボーン]
#   [アメリカ機械工学会]
#   [All_About]
#   [ベルナリオ]
#   クライストチャーチ大聖堂
#   [G検定]
#   [名誉支部長]
#   [特例公債法]
#   [慣性航法装置]
#   [鍵のかかる部屋]
#   [ニーオーレスン]
#   ブルーブック
#   アイルランド海
#   [マクロスΔ]
#   [神癒]
#   [ミラクル・バス]
#   [憲法擁護国民連合]
#   ウェイバー公示
#   三月ウサギ
#   下越地方
#   [ヒロモト森一]
#   [ゴマフエダイ]
#   就労ビザ
#   [計算資源]
#   [フェリーニのローマ]
#   [wikt:dolce]
#   [鉄砲山古墳]
#   オーベルト
#   [大友義右]
#   [中山神社_(下関市)]
#   荒城
#   [オジェ・ル・ダノワ]
#   東部標準時
#   [日本マナー・プロトコール協会]
#   大学令
#   [簡易貫入試験]
#   [ノーザンポラリス]
#   バルログ
#   [同和問題]
#   [Ambitious*]
#   [パトリック・アーノルド]
#   [インドア]
#   [フォトマスク]
#   [ヌノ・アルヴァレス・ペレイラ]
#   [佐竹義藤]
#   [全日本学生落語選手権・策伝大賞]
#   [触手]
#   [アンブローズ]
#   [コールジュ]
#   疑似科学
#   [豊前街道]
#   ろんぎ
#   熱転写
#   一芸入試
#   [サヒーフ・ムスリム]
#   [田北鎮周]
#   [1949年のル・マン24時間レース]
#   [ユトレヒト音楽院]
#   カーナ
#   [室蘭大谷高等学校]
#   ホルマリン
#   [ヨナグニサン]
#   建暦
#   [タカカウ滝]
#   職
#   [国際興業バス西浦和営業所]
#   パゴダ
#   [ルイブールの戦い]
#   [ヨゼフィーネ・ムッツェンバッヒェル]
#   [サバイバルゲーム]
#   [ミサイル防衛局]
#   地車
#   [藤右衛門川]
#   酢漬け
#   [ジゴロー]
#   [マンディ・メイヤー]
#   ベルベラ
#   [愛知県立半田商業高等学校]
#   [量子もつれ]
#   [アペタイト・フォー・ディストラクション]
#   [JOKER_(Janne_Da_Arcのアルバム)]
#   コアレス
#   [馬公空港]
#   [メノン_(対話篇)]
#   [クリア・ノートとヴィノー]
#
# Cluster 4:
#   [クラーネンブルク]
#   [アヴェンティーノ]
#   [サマンサ・エッガー]
#   [ウォンビン]
#   [モロトフ・プラン]
#   [ジョニー・ロットン]
#   [徳永善也]
#   [楢]
#   体育会系
#   [セルゲーイ・ボンダルチューク]
#   [ホルトホール大分]
#   [X_(game_series)]
#   [全粒粉]
#   [ヒートホーク]
#   らいにん
#   [バレイロス]
#   [デ・ハビランド_スペクター]
#   [2011年イエメン騒乱]
#   表現促進現象
#   [フェルミエネルギー]
#   ゆかり
#   の責任
#   [蒼鷹]
#   [プリムラ]
#   [滕王閣]
#   [ポーランド王領プロシア]
#   [ペアノ曲線]
#   レイクス
#   [バスマチ]
#   [eXtended_Global_Platform]
#   [小松清廉]
#   [ウィグワム]
#   [ラパッロ条約_(1920年)]
#   [2008年ウィンブルドン選手権男子シングルス]
#   [ベーシックインカム]
#   [Merry]
#   [カールトン・バレット]
#   [AIBA世界ボクシング選手権]
#   [海兵隊讃歌]
#   地震動
#   [無線呼び出し]
#   [漁民]
#   [デュラム小麦]
#   京浜地区
#   [ベンゾジオキサン]
#   山小屋
#   [オーエンスタンレー山脈]
#   [ウルトラマンゼロ_THE_MOVIE_超決戦!ベリアル銀河帝国]
#   [ウムラウト]
#   光風
#   [戸畑バイパス]
#   [I_BELIEVE_(華原朋美の曲)]
#   カイゼル髭
#   [城絵図]
#   [超次元ゲイム_ネプテューヌ]
#   [首都高速2号目黒線]
#   [楽屋裏]
#   となり合
#   [Pearl]
#   [スタンステッド空港]
#   [ブダペスト・スポーツアリーナ]
#   [名古屋鉄道デセホ700形電車]
#   [山城大橋]
#   [山陽自動車運送]
#   コロンビア政府
#   ドットネット
#   [ニューモデル軍]
#   [TROUBLE_IN_PARADISE]
#   [長野県議会]
#   バイオコンピューター
#   毎日書道会
#   [ORANGE_RANGE]
#   芸能界
#   [エイコサン]
#   [京胡]
#   [アカウキクサ]
#   [常磐高等学校_(福岡県)]
#   [林家ペー]
#   [万治の大火]
#   [画数]
#   [ギンザメ目]
#   [インカ道]
#   大系
#   [サアド・アル＝アブドゥッラー・アッ＝サバーハ]
#   [Microsoft_Office_SharePoint_Server]
#   [蛆虫]
#   [WS-Addressing]
#   [ブライス・ハーパー]
#   [ワイメア_(ハワイ島)]
#   [賀盧]
#   [三木小野インターチェンジ]
#   [かがり火]
#   [乗合行為]
#   東洲斎
#   [オッフェンバッハ・アム・マイン造形大学]
#   [ニューロティック・アウトサイダーズ]
#   [旦那]
#   [北殿駅]
#   [ロマン・ウンゲルン]
#   [線引き問題]
# Total vectors: (564932, 200), Total clusters: 564932

# %%
import logging
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, silhouette_samples
from sklearn.utils import resample

# ログ設定
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

def plot_cluster_word_counts(cluster_indices):
    logging.info("Calculating the number of words per cluster...")
    unique, counts = np.unique(cluster_indices, return_counts=True)
    cluster_counts = dict(zip(unique, counts))

    logging.info("Plotting the number of words per cluster...")
    plt.figure(figsize=(10, 6))
    sns.barplot(x=list(cluster_counts.keys()), y=list(cluster_counts.values()), palette="viridis")
    plt.title('Number of Words per Cluster')
    plt.xlabel('Cluster')
    plt.ylabel('Number of Words')
    plt.show()

def plot_cluster_centers_pca(word_vectors, kmeans):
    logging.info("Performing PCA on word vectors...")
    pca = PCA(n_components=2)
    word_vectors_pca = pca.fit_transform(word_vectors)
    cluster_centers_pca = pca.transform(kmeans.cluster_centers_)

    logging.info("Plotting word vectors and cluster centers...")
    plt.figure(figsize=(10, 8))
    plt.scatter(word_vectors_pca[:, 0], word_vectors_pca[:, 1], c=cluster_indices, cmap='viridis', alpha=0.5, s=10)
    plt.scatter(cluster_centers_pca[:, 0], cluster_centers_pca[:, 1], c='red', marker='x', s=100, label='Cluster Centers')
    plt.title('Word Vectors and Cluster Centers (PCA)')
    plt.xlabel('PCA Component 1')
    plt.ylabel('PCA Component 2')
    plt.legend()
    plt.show()
    return pca

def plot_silhouette_analysis(word_vectors, cluster_indices, num_clusters):
    logging.info("Calculating silhouette score...")
    sampled_word_vectors, sampled_cluster_indices = resample(word_vectors, cluster_indices, n_samples=int(0.01*len(word_vectors)), random_state=42)
    silhouette_avg = silhouette_score(sampled_word_vectors, sampled_cluster_indices)
    logging.info(f"Silhouette Score: {silhouette_avg:.3f}")

    logging.info("Plotting silhouette scores for each cluster...")
    sample_silhouette_values = silhouette_samples(sampled_word_vectors, sampled_cluster_indices)
    y_lower = 10

    plt.figure(figsize=(10, 8))

    # クラスターごとのサンプル数が大きい場合に進行状況を表示
    for i in tqdm(range(num_clusters), desc="Clusters processed"):
        ith_cluster_silhouette_values = sample_silhouette_values[sampled_cluster_indices == i]
        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = plt.cm.nipy_spectral(float(i) / num_clusters)
        plt.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        plt.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10

    plt.title("Silhouette Plot for Various Clusters")
    plt.xlabel("Silhouette Coefficient Values")
    plt.ylabel("Cluster")

    plt.axvline(x=silhouette_avg, color="red", linestyle="--")
    plt.show()

# %%
plot_cluster_word_counts(cluster_indices)
plot_cluster_centers_pca(noun_vectors, kmeans)
plot_silhouette_analysis(noun_vectors, cluster_indices, num_clusters)
# Out:
# 2024-09-16 01:58:58,466 - INFO - Calculating the number of words per cluster...
# 2024-09-16 01:58:58,489 - INFO - Plotting the number of words per cluster...
# 2024-09-16 01:58:58,529 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /var/folders/2x/p5h03dq11m7b230v42t51spw0000gn/T/ipykernel_34158/183901401.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=list(cluster_counts.keys()), y=list(cluster_counts.values()), palette="viridis")
# 2024-09-16 01:58:58,537 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-16 01:58:58,701 - INFO - Performing PCA on word vectors...
# 2024-09-16 01:58:59,057 - INFO - Plotting word vectors and cluster centers...
# 2024-09-16 01:59:04,982 - INFO - Calculating silhouette score...
# 2024-09-16 01:59:05,409 - INFO - Silhouette Score: -0.100
# 2024-09-16 01:59:05,413 - INFO - Plotting silhouette scores for each cluster...
# Clusters processed: 100%|██████████| 10/10 [00:00<00:00, 405.55it/s]
