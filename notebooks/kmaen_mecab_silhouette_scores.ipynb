# %%
# word2vecの分類　（kmeans Scikit-learn mecab）

Scikit-learnを使用してクラスター分類を行う。
Mecabによって単語などの分割を行う。
Kmeansのクラスター数を調べてみる。
PCAを基準としてどの値が最も使えるか調べる

# %%
# 使用ライブラリのインストール

# !pip install -U scikit-learn

# !pip install --upgrade gensim

# !pip install  --upgrade mecab

# !brew install mecab
# !brew install mecab-ipadic

# %%
import MeCab
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

def kmeans_cluster_nouns_with_silhouette(model_path, cluster_range, batch_size=1000):
    """
    名詞に対してK-meansクラスタリングを行い、シルエットスコアを計算し、クラスタ数ごとにスコアをプロットする。
    """
    # Word2Vecモデルの読み込み
    model = KeyedVectors.load_word2vec_format(model_path, binary=False)

    # MeCabの初期化
    mecab = MeCab.Tagger('-r /opt/homebrew/etc/mecabrc -d /opt/homebrew/lib/mecab/dic/ipadic')

    # 名詞を格納するリスト
    nouns = []

    # モデル内の単語を解析して名詞を抽出
    for idx, word in enumerate(model.index_to_key):
        parsed = mecab.parse(word)
        for line in parsed.splitlines():
            if line == 'EOS':
                break
            fields = line.split('\t')
            if len(fields) > 1:
                pos_info = fields[1].split(',')
                if pos_info[0] == '名詞':
                    nouns.append(word)
                    break
        if len(nouns) >= batch_size:
            break  # バッチサイズに到達したら停止

    # 名詞のベクトルを取得
    noun_vectors = np.array([model[word] for word in nouns])

    silhouette_scores = []
    for num_clusters in cluster_range:
        print(f"Processing {num_clusters} clusters...")

        # K-meansクラスタリングの実行
        kmeans = KMeans(n_clusters=num_clusters, random_state=0)
        cluster_indices = kmeans.fit_predict(noun_vectors)

        # シルエットスコアの計算
        score = silhouette_score(noun_vectors, cluster_indices)
        silhouette_scores.append(score)
        print(f"Silhouette Score for {num_clusters} clusters: {score}")

    # クラスタ数とシルエットスコアのグラフを描画
    plt.figure(figsize=(10, 6))
    plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='-', color='b')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Silhouette Score')
    plt.title('Silhouette Scores for Different Cluster Numbers')
    plt.grid(True)
    plt.show()

# %%
# 例として関数を呼び出す
model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
cluster_range = range(2, 101, 10)  # クラスタ数の範囲を指定

kmeans_cluster_nouns_with_silhouette(model_path, cluster_range)
# Out:
# Processing 2 clusters...
# Silhouette Score for 2 clusters: 0.0504775308072567
# Processing 12 clusters...
# Silhouette Score for 12 clusters: 0.06067712604999542
# Processing 22 clusters...
# Silhouette Score for 22 clusters: 0.06969434767961502
# Processing 32 clusters...
# Silhouette Score for 32 clusters: 0.07134007662534714
# Processing 42 clusters...
# Silhouette Score for 42 clusters: 0.07593437284231186
# Processing 52 clusters...
# Silhouette Score for 52 clusters: 0.08057185262441635
# Processing 62 clusters...
# Silhouette Score for 62 clusters: 0.07982319593429565
# Processing 72 clusters...
# Silhouette Score for 72 clusters: 0.07036957144737244
# Processing 82 clusters...
# Silhouette Score for 82 clusters: 0.07971728593111038
# Processing 92 clusters...
# Silhouette Score for 92 clusters: 0.07896102964878082

# %%
# 例として関数を呼び出す
model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
cluster_range = range(2, 1001, 10)  # クラスタ数の範囲を指定

kmeans_cluster_nouns_with_silhouette(model_path, cluster_range)
# Out:
# Processing 2 clusters...
# Silhouette Score for 2 clusters: 0.0504775308072567
# Processing 12 clusters...
# Silhouette Score for 12 clusters: 0.06067712604999542
# Processing 22 clusters...
# Silhouette Score for 22 clusters: 0.06969434767961502
# Processing 32 clusters...
# Silhouette Score for 32 clusters: 0.07134007662534714
# Processing 42 clusters...
# Silhouette Score for 42 clusters: 0.07593437284231186
# Processing 52 clusters...
# Silhouette Score for 52 clusters: 0.08057185262441635
# Processing 62 clusters...
# Silhouette Score for 62 clusters: 0.07982319593429565
# Processing 72 clusters...
# Silhouette Score for 72 clusters: 0.07036957144737244
# Processing 82 clusters...
# Silhouette Score for 82 clusters: 0.07971728593111038
# Processing 92 clusters...
# Silhouette Score for 92 clusters: 0.07896102964878082
# Processing 102 clusters...
# Silhouette Score for 102 clusters: 0.07798600196838379
# Processing 112 clusters...
# Silhouette Score for 112 clusters: 0.07860228419303894
# Processing 122 clusters...
# Silhouette Score for 122 clusters: 0.07976610213518143
# Processing 132 clusters...
# Silhouette Score for 132 clusters: 0.08023785054683685
# Processing 142 clusters...
# Silhouette Score for 142 clusters: 0.08455538749694824
# Processing 152 clusters...
# Silhouette Score for 152 clusters: 0.08109182119369507
# Processing 162 clusters...
# Silhouette Score for 162 clusters: 0.08480153232812881
# Processing 172 clusters...
# Silhouette Score for 172 clusters: 0.0858197957277298
# Processing 182 clusters...
# Silhouette Score for 182 clusters: 0.08878424018621445
# Processing 192 clusters...
# Silhouette Score for 192 clusters: 0.08923166245222092
# Processing 202 clusters...
# Silhouette Score for 202 clusters: 0.0906880795955658
# Processing 212 clusters...
# Silhouette Score for 212 clusters: 0.09152215719223022
# Processing 222 clusters...
# Silhouette Score for 222 clusters: 0.09374705702066422
# Processing 232 clusters...
# Silhouette Score for 232 clusters: 0.09691503643989563
# Processing 242 clusters...
# Silhouette Score for 242 clusters: 0.09722555428743362
# Processing 252 clusters...
# Silhouette Score for 252 clusters: 0.09844756871461868
# Processing 262 clusters...
# Silhouette Score for 262 clusters: 0.0989581048488617
# Processing 272 clusters...
# Silhouette Score for 272 clusters: 0.10076867789030075
# Processing 282 clusters...
# Silhouette Score for 282 clusters: 0.10151170194149017
# Processing 292 clusters...
# Silhouette Score for 292 clusters: 0.10382260382175446
# Processing 302 clusters...
# Silhouette Score for 302 clusters: 0.10442737489938736
# Processing 312 clusters...
# Silhouette Score for 312 clusters: 0.10456909984350204
# Processing 322 clusters...
# Silhouette Score for 322 clusters: 0.1048588827252388
# Processing 332 clusters...
# Silhouette Score for 332 clusters: 0.10595691204071045
# Processing 342 clusters...
# Silhouette Score for 342 clusters: 0.10589352250099182
# Processing 352 clusters...
# Silhouette Score for 352 clusters: 0.10692933201789856
# Processing 362 clusters...
# Silhouette Score for 362 clusters: 0.10875300318002701
# Processing 372 clusters...
# Silhouette Score for 372 clusters: 0.10877420008182526
# Processing 382 clusters...
# Processing 792 clusters...
# Silhouette Score for 792 clusters: 0.09228043258190155
# Processing 802 clusters...
# Silhouette Score for 802 clusters: 0.08914691209793091
# Processing 812 clusters...
# Silhouette Score for 812 clusters: 0.08837839215993881
# Processing 822 clusters...
# Silhouette Score for 822 clusters: 0.08738613873720169
# Processing 832 clusters...
# Silhouette Score for 832 clusters: 0.08505617082118988
# Processing 842 clusters...
# Silhouette Score for 842 clusters: 0.08221454918384552
# Processing 852 clusters...
# Silhouette Score for 852 clusters: 0.07691796869039536
# Processing 862 clusters...
# Silhouette Score for 862 clusters: 0.07339435070753098
# Processing 872 clusters...
# Silhouette Score for 872 clusters: 0.07118083536624908
# Processing 882 clusters...
# Silhouette Score for 882 clusters: 0.06489500403404236
# Processing 892 clusters...
# Silhouette Score for 892 clusters: 0.05598314851522446
# Processing 902 clusters...
# Silhouette Score for 902 clusters: 0.049997925758361816
# Processing 912 clusters...
# Silhouette Score for 912 clusters: 0.04337035492062569
# Processing 922 clusters...
# Silhouette Score for 922 clusters: 0.03388005495071411
# Processing 932 clusters...
# Silhouette Score for 932 clusters: 0.027519119903445244
# Processing 942 clusters...
# Silhouette Score for 942 clusters: 0.02258332073688507
# Processing 952 clusters...
# Silhouette Score for 952 clusters: 0.017633672803640366
# Processing 962 clusters...
# Silhouette Score for 962 clusters: 0.012324447743594646
# Processing 972 clusters...
# Silhouette Score for 972 clusters: 0.008503011427819729
# Processing 982 clusters...
# Silhouette Score for 982 clusters: 0.004623944405466318
# Processing 992 clusters...
# Silhouette Score for 992 clusters: 0.0019122115336358547

# %%
# 例として関数を呼び出す
model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
cluster_range = range(2, 600, 1)  # クラスタ数の範囲を指定

kmeans_cluster_nouns_with_silhouette(model_path, cluster_range)
# Out:
# Processing 2 clusters...
# Silhouette Score for 2 clusters: 0.0504775308072567
# Processing 3 clusters...
# Silhouette Score for 3 clusters: 0.05347410589456558
# Processing 4 clusters...
# Silhouette Score for 4 clusters: 0.048717040568590164
# Processing 5 clusters...
# Silhouette Score for 5 clusters: 0.04833913594484329
# Processing 6 clusters...
# Silhouette Score for 6 clusters: 0.04777564853429794
# Processing 7 clusters...
# Silhouette Score for 7 clusters: 0.050448864698410034
# Processing 8 clusters...
# Silhouette Score for 8 clusters: 0.0506659597158432
# Processing 9 clusters...
# Silhouette Score for 9 clusters: 0.053992122411727905
# Processing 10 clusters...
# Silhouette Score for 10 clusters: 0.05658397823572159
# Processing 11 clusters...
# Silhouette Score for 11 clusters: 0.05556834489107132
# Processing 12 clusters...
# Silhouette Score for 12 clusters: 0.06067712604999542
# Processing 13 clusters...
# Silhouette Score for 13 clusters: 0.06320036947727203
# Processing 14 clusters...
# Silhouette Score for 14 clusters: 0.06165005639195442
# Processing 15 clusters...
# Silhouette Score for 15 clusters: 0.06203791871666908
# Processing 16 clusters...
# Silhouette Score for 16 clusters: 0.06378912925720215
# Processing 17 clusters...
# Silhouette Score for 17 clusters: 0.06499084830284119
# Processing 18 clusters...
# Silhouette Score for 18 clusters: 0.06773225218057632
# Silhouette Score for 581 clusters: 0.1102956086397171
# Processing 582 clusters...
# Silhouette Score for 582 clusters: 0.11029697954654694
# Processing 583 clusters...
# Silhouette Score for 583 clusters: 0.10979710519313812
# Processing 584 clusters...
# Silhouette Score for 584 clusters: 0.10963772237300873
# Processing 585 clusters...
# Silhouette Score for 585 clusters: 0.1093447133898735
# Processing 586 clusters...
# Silhouette Score for 586 clusters: 0.1092274859547615
# Processing 587 clusters...
# Silhouette Score for 587 clusters: 0.10897193849086761
# Processing 588 clusters...
# Silhouette Score for 588 clusters: 0.10971967875957489
# Processing 589 clusters...
# Silhouette Score for 589 clusters: 0.11051007360219955
# Processing 590 clusters...
# Silhouette Score for 590 clusters: 0.11026283353567123
# Processing 591 clusters...
# Silhouette Score for 591 clusters: 0.11008444428443909
# Processing 592 clusters...
# Silhouette Score for 592 clusters: 0.11022471636533737
# Processing 593 clusters...
# Silhouette Score for 593 clusters: 0.10982893407344818
# Processing 594 clusters...
# Silhouette Score for 594 clusters: 0.10960134863853455
# Processing 595 clusters...
# Silhouette Score for 595 clusters: 0.10946585237979889
# Processing 596 clusters...
# Silhouette Score for 596 clusters: 0.10917475819587708
# Processing 597 clusters...
# Silhouette Score for 597 clusters: 0.10896903276443481
# Processing 598 clusters...
# Silhouette Score for 598 clusters: 0.10896307229995728
# Processing 599 clusters...
# Silhouette Score for 599 clusters: 0.10905198007822037

# %%
import MeCab
from gensim.models import KeyedVectors
from sklearn.cluster import KMeans
import numpy as np
import random
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score

def kmeans_cluster_nouns_with_silhouette(model_path, cluster_range, batch_size=10000):
    """
    名詞に対してK-meansクラスタリングを行い、シルエットスコアを計算し、クラスタ数ごとにスコアをプロットする。
    """
    # Word2Vecモデルの読み込み
    model = KeyedVectors.load_word2vec_format(model_path, binary=False)

    # MeCabの初期化
    mecab = MeCab.Tagger('-r /opt/homebrew/etc/mecabrc -d /opt/homebrew/lib/mecab/dic/ipadic')

    # 名詞を格納するリスト
    nouns = []

    # モデル内の単語を解析して名詞を抽出
    for idx, word in enumerate(model.index_to_key):
        parsed = mecab.parse(word)
        for line in parsed.splitlines():
            if line == 'EOS':
                break
            fields = line.split('\t')
            if len(fields) > 1:
                pos_info = fields[1].split(',')
                if pos_info[0] == '名詞':
                    nouns.append(word)
                    break
        if len(nouns) >= batch_size:
            break  # バッチサイズに到達したら停止

    # 名詞のベクトルを取得
    noun_vectors = np.array([model[word] for word in nouns])

    silhouette_scores = []
    for num_clusters in cluster_range:
        print(f"Processing {num_clusters} clusters...")

        # K-meansクラスタリングの実行
        kmeans = KMeans(n_clusters=num_clusters, random_state=0)
        cluster_indices = kmeans.fit_predict(noun_vectors)

        # シルエットスコアの計算
        score = silhouette_score(noun_vectors, cluster_indices)
        silhouette_scores.append(score)
        print(f"Silhouette Score for {num_clusters} clusters: {score}")

    # クラスタ数とシルエットスコアのグラフを描画
    plt.figure(figsize=(10, 6))
    plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='-', color='b')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Silhouette Score')
    plt.title('Silhouette Scores for Different Cluster Numbers')
    plt.grid(True)
    plt.show()

# %%
# 例として関数を呼び出す
model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
cluster_range = range(2, 600, 1)  # クラスタ数の範囲を指定

kmeans_cluster_nouns_with_silhouette(model_path, cluster_range)
# Out:
# Processing 2 clusters...
# Silhouette Score for 2 clusters: 0.03312988579273224
# Processing 3 clusters...
# Silhouette Score for 3 clusters: 0.03092874214053154
# Processing 4 clusters...
# Silhouette Score for 4 clusters: 0.027859607711434364
# Processing 5 clusters...
# Silhouette Score for 5 clusters: 0.029503606259822845
# Processing 6 clusters...
# Silhouette Score for 6 clusters: 0.029197460040450096
# Processing 7 clusters...
# Silhouette Score for 7 clusters: 0.030043866485357285
# Processing 8 clusters...
# Silhouette Score for 8 clusters: 0.02761663869023323
# Processing 9 clusters...
# Silhouette Score for 9 clusters: 0.02894708514213562
# Processing 10 clusters...
# Silhouette Score for 10 clusters: 0.03128395974636078
# Processing 11 clusters...
# Silhouette Score for 11 clusters: 0.01959298364818096
# Processing 12 clusters...
# Silhouette Score for 12 clusters: 0.02117050252854824
# Processing 13 clusters...
# Silhouette Score for 13 clusters: 0.020853009074926376
# Processing 14 clusters...
# Silhouette Score for 14 clusters: 0.02208525873720646
# Processing 15 clusters...
# Silhouette Score for 15 clusters: 0.022708062082529068
# Processing 16 clusters...
# Silhouette Score for 16 clusters: 0.02465365082025528
# Processing 17 clusters...
# Silhouette Score for 17 clusters: 0.027961941435933113
# Processing 18 clusters...
# Silhouette Score for 18 clusters: 0.02887941524386406
# Processing 19 clusters...
# Silhouette Score for 19 clusters: 0.030096447095274925
# Processing 20 clusters...
# Silhouette Score for 20 clusters: 0.03224088251590729
# Processing 21 clusters...
# Silhouette Score for 21 clusters: 0.027669070288538933
# Processing 22 clusters...
# Silhouette Score for 22 clusters: 0.025977548211812973
# Processing 23 clusters...
# Silhouette Score for 23 clusters: 0.02706635743379593
# Processing 24 clusters...
# Silhouette Score for 24 clusters: 0.02775687165558338
# Processing 25 clusters...
# Silhouette Score for 25 clusters: 0.029764313250780106
# Processing 26 clusters...
# Silhouette Score for 26 clusters: 0.030474960803985596
# Processing 27 clusters...
# Silhouette Score for 27 clusters: 0.03326204791665077
# Processing 28 clusters...
# Silhouette Score for 28 clusters: 0.033356133848428726
# Processing 29 clusters...
# Silhouette Score for 29 clusters: 0.034752778708934784
# Processing 30 clusters...
# Silhouette Score for 30 clusters: 0.036558084189891815
# Processing 31 clusters...
# Silhouette Score for 31 clusters: 0.03216519206762314
# Processing 32 clusters...
# Silhouette Score for 32 clusters: 0.03344721719622612
# Processing 33 clusters...
# Silhouette Score for 33 clusters: 0.03454872965812683
# Processing 34 clusters...
# Silhouette Score for 34 clusters: 0.034812286496162415
# Processing 35 clusters...
# Silhouette Score for 35 clusters: 0.036456700414419174
# Processing 36 clusters...
# Silhouette Score for 36 clusters: 0.036925122141838074
# Processing 37 clusters...
# Silhouette Score for 37 clusters: 0.037084124982357025
# Processing 38 clusters...
# Silhouette Score for 38 clusters: 0.03775593265891075
# Processing 39 clusters...
# Silhouette Score for 39 clusters: 0.03825516253709793
# Processing 40 clusters...
# Silhouette Score for 40 clusters: 0.03960838168859482
# Processing 41 clusters...
# Silhouette Score for 41 clusters: 0.03934567794203758
# Processing 42 clusters...
# Silhouette Score for 42 clusters: 0.040841810405254364
# Processing 43 clusters...
# Silhouette Score for 43 clusters: 0.04121161624789238
# Processing 44 clusters...
# Silhouette Score for 44 clusters: 0.04237005487084389
# Processing 45 clusters...
# Silhouette Score for 45 clusters: 0.043222423642873764
# Processing 46 clusters...
# Silhouette Score for 46 clusters: 0.043933428823947906
# Processing 47 clusters...
# Silhouette Score for 47 clusters: 0.04452003911137581
# Processing 48 clusters...
# Silhouette Score for 48 clusters: 0.04512155055999756
# Processing 49 clusters...
# Silhouette Score for 49 clusters: 0.04548141732811928
# Processing 50 clusters...
# Silhouette Score for 50 clusters: 0.0461537204682827
# Processing 51 clusters...
# Silhouette Score for 51 clusters: 0.04633628576993942
# Processing 52 clusters...
# Silhouette Score for 52 clusters: 0.04680793732404709
# Processing 53 clusters...
# Silhouette Score for 53 clusters: 0.04829408600926399
# Processing 54 clusters...
# Silhouette Score for 54 clusters: 0.048536378890275955
# Processing 55 clusters...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 5
#       2 model_path = '../data/japanese_word2vec_vectors.vec'  # モデルのパスを指定
#       3 cluster_range = range(2, 600, 1)  # クラスタ数の範囲を指定
# ----> 5 kmeans_cluster_nouns_with_silhouette(model_path, cluster_range)
#
# Cell In[8], line 49, in kmeans_cluster_nouns_with_silhouette(model_path, cluster_range, batch_size)
#      46 cluster_indices = kmeans.fit_predict(noun_vectors)
#      48 # シルエットスコアの計算
# ---> 49 score = silhouette_score(noun_vectors, cluster_indices)
#      50 silhouette_scores.append(score)
#      51 print(f"Silhouette Score for {num_clusters} clusters: {score}")
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/cluster/_unsupervised.py:141, in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     139     else:
#     140         X, labels = X[indices], labels[indices]
# --> 141 return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/cluster/_unsupervised.py:305, in silhouette_samples(X, labels, metric, **kwds)
#     301 kwds["metric"] = metric
#     302 reduce_func = functools.partial(
#     303     _silhouette_reduce, labels=labels, label_freqs=label_freqs
#     304 )
# --> 305 results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func, **kwds))
#     306 intra_clust_dists, inter_clust_dists = results
#     307 intra_clust_dists = np.concatenate(intra_clust_dists)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/pairwise.py:2172, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2170 else:
#    2171     X_chunk = X[sl]
# -> 2172 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    2173 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    2174     metric, None
#    2175 ) is euclidean_distances:
#    2176     # zeroing diagonal, taking care of aliases of "euclidean",
#    2177     # i.e. "l2"
#    2178     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/pairwise.py:2375, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2372         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2373     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2375 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/pairwise.py:1893, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1890 X, Y, dtype = _return_float_dtype(X, Y)
#    1892 if effective_n_jobs(n_jobs) == 1:
# -> 1893     return func(X, Y, **kwds)
#    1895 # enforce a threading backend to prevent data communication overhead
#    1896 fd = delayed(_dist_wrapper)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/pairwise.py:372, in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     366     if Y_norm_squared.shape != (1, Y.shape[0]):
#     367         raise ValueError(
#     368             f"Incompatible dimensions for Y of shape {Y.shape} and "
#     369             f"Y_norm_squared of shape {original_shape}."
#     370         )
# --> 372 return _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/pairwise.py:410, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     408     distances += XX
#     409     distances += YY
# --> 410 np.maximum(distances, 0, out=distances)
#     412 # Ensure that distances between vectors and themselves are set to 0.0.
#     413 # This may not be the case due to floating point rounding errors.
#     414 if X is Y:
#
# KeyboardInterrupt:
